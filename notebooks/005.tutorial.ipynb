# %% [markdown]
# 004に対して以下を追加
#
# 承知いたしました。グローバルアイテム埋め込みの更新をFedAvg（Federated Averaging）に基づいて行う実装を示します。
#
# FedAvgでは、各クライアントからアップロードされたモデルパラメータ（ここでは`local_item_embedding.weight`）を、そのクライアントのデータセットサイズ（または他の貢献度指標）で重み付けして平均します。
#
# **変更点:**
#
# 1.  **`ClientModel.forward` の変更なし**: クライアントモデルからアップロードされる重みはこれまで通り`self.local_item_embedding.weight`です。
# 2.  **`Server.aggregate_item_embeddings` の修正**:
#       * `user_graph_adj` と `sorted_user_ids` を使ったグラフ畳み込みのロジックは残します。
#       * そのグラフ畳み込みの結果得られた `R_tensor` を直接平均するのではなく、FedAvg の重み付け平均を適用します。
#       * 重み付けには、各クライアント（ユーザー）が持つインタラクションの総数を使用します。これは、`len(dataloader.dataset)` で取得できます。
#       * ※ **ただし、論文はFedAVG的なやり方は実行しておらず、004のように単純に平均をとって$\theta_{global}$を更新している$**
# 3.  **学習ループの修正**:
#       * 各クライアントが自身のデータセットサイズをサーバーに報告できるようにします。
#       * サーバーは、報告されたデータセットサイズを使って重み付き平均を計算します。

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Subset
from transformers import AutoModel, AutoTokenizer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# 軽量 LLM 埋め込みモデルのロード (変更なし)
plm_model_name = "sentence-transformers/all-MiniLM-L6-v2"
plm_tokenizer = AutoTokenizer.from_pretrained(plm_model_name)
plm_model = AutoModel.from_pretrained(plm_model_name)

# PLMは学習済みモデルのため、勾配計算を無効化
for param in plm_model.parameters():
    param.requires_grad = False

plm_embedding_dim = plm_model.config.hidden_size
print(f"PLM embedding dimension: {plm_embedding_dim}")


class ClientModel(nn.Module):
    def __init__(self, num_items, item_embedding_dim, plm_model, plm_embedding_dim, joint_embedding_output_dim):
        super(ClientModel, self).__init__()
        self.plm_model = plm_model
        
        # Joint Embedding Layer (module parameter θ_user)
        self.user_joint_embedding_linear = nn.Linear(plm_embedding_dim, joint_embedding_output_dim)
        
        # Item Embedding Layer (module parameter θ_item)
        self.local_item_embedding = nn.Embedding(num_items, item_embedding_dim)

        # User Feature Refinement MLP (module parameter θ_umlp)
        self.user_mlp = nn.Sequential(
            nn.Linear(joint_embedding_output_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32)
        )

        # Predictive Scoring Function (module parameter θ_score)
        self.prediction_mlp = nn.Sequential(
            nn.Linear(item_embedding_dim + joint_embedding_output_dim, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 1)
        )

    def forward(self, user_ids, item_ids, user_texts_batch): 
        encoded_input = plm_tokenizer(user_texts_batch, padding=True, truncation=True, return_tensors='pt')
        plm_output = self.plm_model(**encoded_input).last_hidden_state[:, 0, :]

        user_raw_embedding = self.user_joint_embedding_linear(plm_output)
        user_embedding = self.user_mlp(user_raw_embedding)

        item_embedding = self.local_item_embedding(item_ids)

        combined_features = torch.cat((user_embedding, item_embedding), dim=1)
        logits = self.prediction_mlp(combined_features)
        predictions = torch.sigmoid(logits)

        return predictions, self.user_joint_embedding_linear.weight, self.local_item_embedding.weight


class Server:
    def __init__(self, num_users, num_items, item_embedding_dim, joint_embedding_output_dim):
        self.global_item_embedding = nn.Embedding(num_items, item_embedding_dim)
        self.num_users = num_users
        self.num_items = num_items
        self.item_embedding_dim = item_embedding_dim
        self.joint_embedding_output_dim = joint_embedding_output_dim

    def build_user_relationship_graph(self, user_linear_weights_map):
        """
        各ユーザーのuser_joint_embedding_linear.weightからユーザー関係グラフを構築します。
        論文の式 (15) に基づいています。 [cite: 106]

        Args:
            user_linear_weights_map (dict): {user_id: user_joint_embedding_linear.weight.data (d1, d2) Tensor}

        Returns:
            np.ndarray: ユーザーグラフの隣接行列 (NumPy配列)
            list: グラフのノード順に対応するユーザーIDのリスト
        """
        sorted_user_ids = sorted(user_linear_weights_map.keys())
        if not sorted_user_ids:
            return np.zeros((0, 0)), []

        user_weight_vectors = np.array([
            user_linear_weights_map[u_id].flatten().cpu().numpy() for u_id in sorted_user_ids
        ])

        similarity_matrix = cosine_similarity(user_weight_vectors)
        user_graph_adj = similarity_matrix

        return user_graph_adj, sorted_user_ids

    def aggregate_item_embeddings(self, user_local_item_weights, user_graph_adj, sorted_user_ids, client_data_sizes):
        """
        ユーザー関係グラフに基づいてアイテム埋め込みを集約し、FedAvgでグローバル埋め込みを更新します。

        Args:
            user_local_item_weights (dict): {user_id: local_item_embedding.weight.data (Tensor)}
            user_graph_adj (np.ndarray): ユーザーグラフの隣接行列
            sorted_user_ids (list): user_graph_adj のノード順に対応するユーザーIDのリスト
            client_data_sizes (dict): {user_id: そのユーザーのデータセットサイズ}

        Returns:
            torch.Tensor: 更新されたグローバルアイテム埋め込みの重み
        """
        if not user_local_item_weights:
            return self.global_item_embedding.weight.data

        # グラフの順序に合わせて各ユーザーのアイテム埋め込みを行列Aとしてまとめる
        item_embedding_matrix_A = torch.stack([
            user_local_item_weights[u_id] for u_id in sorted_user_ids
        ]) # (num_users, num_items, item_embedding_dim)

        # グラフの正規化 (S'')今回は簡易的に行なっている
        # INFO:論文でのグラフの正規化の流れ
        # 1. user_graph_adjのi番目の横ベクトルを抽出
        # 2. 横ベクトルの値を降順に並べた時のtop-kとなるインデックスのListを取得
        # 3. top-kのインデックスに対応するところの値を 1/neighborhood_sizeと固定値とし、他のインデックスを0にした横ベクトルを作成
        # 4. それを全ユーザに対して実行し、縦積みしていく.
        row_sums_graph = np.sum(user_graph_adj, axis=1, keepdims=True)
        row_sums_graph[row_sums_graph == 0] = 1 
        normalized_user_graph_adj = user_graph_adj / row_sums_graph

        normalized_user_graph_adj_tensor = torch.tensor(normalized_user_graph_adj, dtype=torch.float32)

        # グラフ畳み込み (R = S'' A)
        # INFO:
        # - S'': ユーザ数 x ユーザ数の正規化された隣接行列
        # - A: ユーザ数 x アイテム数 x アイテム埋め込み次元
        R_tensor = torch.einsum('ij, jkd -> ikd', normalized_user_graph_adj_tensor, item_embedding_matrix_A)

        # グローバルアイテム埋め込みの更新 (FedAvg: D = degree matrix at the time of aggregation)
        # R_tensorの各行は、各ユーザーがグラフ畳み込みによって集約されたアイテム埋め込み
        # FedAvgでは、これらをクライアントのデータセットサイズで重み付けして平均する

        total_data_size = sum(client_data_sizes[u_id] for u_id in sorted_user_ids)
        if total_data_size == 0:
            return self.global_item_embedding.weight.data # データがない場合は更新しない

        weighted_sum_item_embeddings = torch.zeros_like(self.global_item_embedding.weight.data)

        for i, u_id in enumerate(sorted_user_ids):
            weight = client_data_sizes[u_id] / total_data_size
            weighted_sum_item_embeddings += weight * R_tensor[i] # R_tensorのi番目の行はユーザーu_idの集約されたアイテム埋め込み

        new_global_item_embedding_weight = weighted_sum_item_embeddings

        # サーバーのグローバルアイテム埋め込みを直接更新
        self.global_item_embedding.weight.data.copy_(new_global_item_embedding_weight)

        return self.global_item_embedding.weight.data


# データセットの準備とクライアントへの分割 (1クライアント1ユーザー)
num_users = 100
num_items = 50
num_clients = num_users 

user_texts = {i: f"This user likes movies about {i % 5} and enjoys {i % 3}." for i in range(num_users)}

interactions_list = []
user_interaction_history = defaultdict(list) 

for u_id in range(num_users):
    for i_id in range(num_items):
        if np.random.rand() > 0.7:
            interactions_list.append([u_id, i_id, 1])
            user_interaction_history[u_id].append(i_id) 
        else:
            interactions_list.append([u_id, i_id, 0])

interactions = torch.tensor(interactions_list, dtype=torch.float32)

client_user_map = {} 
client_datasets = {}
client_original_data_sizes = {} # 各クライアントのデータセットサイズを保存
for u_id in range(num_users):
    client_id = u_id 
    client_user_map[client_id] = u_id 
    
    client_interactions_indices = [i for i, (u, _, _) in enumerate(interactions_list) if u == u_id]
    
    if not client_interactions_indices:
        print(f"Warning: User {u_id} has no interactions. Client {client_id} will have an empty dataset.")
        client_subset = TensorDataset(
            torch.empty(0, dtype=torch.long), 
            torch.empty(0, dtype=torch.long), 
            torch.empty(0, dtype=torch.float32)
        )
        client_original_data_sizes[client_id] = 0
    else:
        user_interaction_data_for_client = []
        for idx in client_interactions_indices:
            u_id_data, i_id_data, label_data = interactions_list[idx]
            user_interaction_data_for_client.append((u_id_data, i_id_data, label_data))

        users_tensor = torch.tensor([d[0] for d in user_interaction_data_for_client], dtype=torch.long)
        items_tensor = torch.tensor([d[1] for d in user_interaction_data_for_client], dtype=torch.long)
        labels_tensor = torch.tensor([d[2] for d in user_interaction_data_for_client], dtype=torch.float32)

        client_subset = TensorDataset(users_tensor, items_tensor, labels_tensor)
        client_original_data_sizes[client_id] = len(client_subset)
    
    client_datasets[client_id] = DataLoader(client_subset, batch_size=min(32, max(1, len(client_subset))), shuffle=True)

print(f"Number of users: {num_users}")
print(f"Number of items: {num_items}")
print(f"Total interactions: {len(interactions)}")
print(f"Number of clients (1 client per user): {num_clients}")


# モデルのハイパーパラメータ
item_embedding_dim = 32
joint_embedding_output_dim = 32 

# サーバーのインスタンス化
server = Server(num_users, num_items, item_embedding_dim, joint_embedding_output_dim)

# 各クライアントのモデルを辞書で保持
client_models = {}
client_optimizers = {}
for client_id in range(num_clients):
    client_models[client_id] = ClientModel(
        num_items,
        item_embedding_dim,
        plm_model,
        plm_embedding_dim,
        joint_embedding_output_dim
    )
    # NOTE:
    # クライアントごとに最適化するパラメータを設定
    # ここでは、user_joint_embedding_linear, local_item_embedding, prediction_layer が対象
    # 単純にoptim.Adam(params = client_models[client_id].parameters(), lr=0.001)とすると、
    # PLMも学習可能パラメータとなってしまうので、
    # PLMのパラメータを除外したパラメータのみを取得してから、設定する.
    trainable_params = [
        p for name, p in client_models[client_id].named_parameters()
        if not name.startswith('plm_model.')
    ]

    client_optimizers[client_id] = optim.Adam(
        params=trainable_params,
        lr=0.001
    )

# 学習ループ (フェデレーテッド学習ラウンド)
num_communication_rounds = 10
local_epochs = 1 

for round_num in range(num_communication_rounds):
    print(f"\n--- Communication Round {round_num + 1}/{num_communication_rounds} ---")

    # サーバーからグローバルアイテム埋め込みをクライアントに配布
    for client_id in range(num_clients):
        client_models[client_id].local_item_embedding.weight.data.copy_(server.global_item_embedding.weight.data)

    user_linear_weights_for_graph = {} # {user_id: user_joint_embedding_linear.weight.data (d1, d2) Tensor}
    user_local_item_weights_to_server = {} # {user_id: local_item_embedding.weight.data (Tensor)}
    client_reported_data_sizes = {} # クライアントが報告するデータセットサイズ

    # クライアントのローカル学習
    for client_id in range(num_clients):
        model = client_models[client_id]
        optimizer = client_optimizers[client_id]
        dataloader = client_datasets[client_id]

        model.train()
        local_loss = 0

        current_user_id = client_user_map[client_id] 

        # クライアントが持つデータセットサイズを報告
        client_reported_data_sizes[current_user_id] = client_original_data_sizes[client_id]

        if len(dataloader.dataset) == 0:
            print(f"  Client {client_id} (User {current_user_id}) has no interactions, skipping local training.")
            # 訓練されなかったクライアントのために、現在のモデルの重み（グローバル初期化時と同じ）をアップロード
            user_linear_weights_for_graph[current_user_id] = model.user_joint_embedding_linear.weight.data.clone().flatten()
            user_local_item_weights_to_server[current_user_id] = model.local_item_embedding.weight.data.clone()
            continue

        for epoch in range(local_epochs):
            for user_ids_batch, item_ids_batch, labels_batch in dataloader:
                assert torch.all(user_ids_batch == current_user_id) 
                current_user_texts = [user_texts[uid.item()] for uid in user_ids_batch]

                optimizer.zero_grad()
                predictions, user_joint_embedding_linear_weight, local_item_embedding_weight = model(
                    user_ids_batch, item_ids_batch, current_user_texts
                )

                loss = nn.BCELoss()(predictions.squeeze(), labels_batch)

                lambda_reg = 0.01 

                regularization_term = torch.mean(
                    (local_item_embedding_weight - server.global_item_embedding.weight.data)**2
                )

                loss = loss + lambda_reg * regularization_term

                loss.backward()
                optimizer.step()
                local_loss += loss.item()

        user_linear_weights_for_graph[current_user_id] = user_joint_embedding_linear_weight.data.clone()
        user_local_item_weights_to_server[current_user_id] = local_item_embedding_weight.data.clone()

        print(f"  Client {client_id} (User {current_user_id}) local loss: {local_loss / len(dataloader):.4f}")

    # サーバーでの処理
    user_graph_adj, sorted_user_ids_for_graph = server.build_user_relationship_graph(
        user_linear_weights_for_graph
    )

    server.aggregate_item_embeddings(
        user_local_item_weights_to_server, 
        user_graph_adj, 
        sorted_user_ids_for_graph,
        client_reported_data_sizes # データセットサイズをサーバーに渡す
    )

    print(f"Round {round_num + 1} completed. Global item embeddings updated.")

print("Federated training completed.")
# Out:
# PLM embedding dimension: 384
# Number of users: 100
# Number of items: 50
# Total interactions: 5000
# Number of clients (1 client per user): 100
#
# --- Communication Round 1/10 ---
#   Client 0 (User 0) local loss: 0.6820
#   Client 1 (User 1) local loss: 0.7625
#   Client 2 (User 2) local loss: 0.7681
#   Client 3 (User 3) local loss: 0.6766
#   Client 4 (User 4) local loss: 0.7052
#   Client 5 (User 5) local loss: 0.7019
#   Client 6 (User 6) local loss: 0.7625
#   Client 7 (User 7) local loss: 0.7510
#   Client 8 (User 8) local loss: 0.6316
#   Client 9 (User 9) local loss: 0.6711
#   Client 10 (User 10) local loss: 0.6732
#   Client 11 (User 11) local loss: 0.7028
#   Client 12 (User 12) local loss: 0.6996
#   Client 13 (User 13) local loss: 0.6873
#   Client 14 (User 14) local loss: 0.6422
#   Client 15 (User 15) local loss: 0.7532
#   Client 16 (User 16) local loss: 0.8253
#   Client 17 (User 17) local loss: 0.6690
#   Client 18 (User 18) local loss: 0.7269
#   Client 19 (User 19) local loss: 0.6631
#   Client 20 (User 20) local loss: 0.6482
#   Client 21 (User 21) local loss: 0.7422
#   Client 22 (User 22) local loss: 0.6226
#   Client 23 (User 23) local loss: 0.7243
#   Client 24 (User 24) local loss: 0.7496
#   Client 25 (User 25) local loss: 0.6884
#   Client 26 (User 26) local loss: 0.6657
#   Client 27 (User 27) local loss: 0.7034
#   Client 28 (User 28) local loss: 0.6791
#   Client 29 (User 29) local loss: 0.7126
#   Client 30 (User 30) local loss: 0.7152
#   Client 31 (User 31) local loss: 0.6410
#   Client 32 (User 32) local loss: 0.6674
#   Client 33 (User 33) local loss: 0.6555
#   Client 34 (User 34) local loss: 0.7133
#   Client 35 (User 35) local loss: 0.7626
#   Client 36 (User 36) local loss: 0.7020
#   Client 37 (User 37) local loss: 0.7208
#   Client 38 (User 38) local loss: 0.6723
#   Client 39 (User 39) local loss: 0.6943
#   Client 40 (User 40) local loss: 0.6809
#   Client 41 (User 41) local loss: 0.7025
#   Client 42 (User 42) local loss: 0.6907
#   Client 43 (User 43) local loss: 0.6348
#   Client 44 (User 44) local loss: 0.7159
#   Client 45 (User 45) local loss: 0.6619
#   Client 46 (User 46) local loss: 0.6758
#   Client 47 (User 47) local loss: 0.7144
#   Client 48 (User 48) local loss: 0.6538
#   Client 49 (User 49) local loss: 0.7362
#   Client 50 (User 50) local loss: 0.7597
#   Client 51 (User 51) local loss: 0.7768
#   Client 52 (User 52) local loss: 0.6671
#   Client 53 (User 53) local loss: 0.7545
#   Client 54 (User 54) local loss: 0.7433
#   Client 55 (User 55) local loss: 0.6766
#   Client 56 (User 56) local loss: 0.6623
#   Client 57 (User 57) local loss: 0.7836
#   Client 58 (User 58) local loss: 0.6219
#   Client 59 (User 59) local loss: 0.6939
#   Client 60 (User 60) local loss: 0.6196
#   Client 61 (User 61) local loss: 0.6909
#   Client 62 (User 62) local loss: 0.7735
#   Client 63 (User 63) local loss: 0.6901
#   Client 64 (User 64) local loss: 0.7105
#   Client 65 (User 65) local loss: 0.7244
#   Client 66 (User 66) local loss: 0.7199
#   Client 67 (User 67) local loss: 0.7326
#   Client 68 (User 68) local loss: 0.7393
#   Client 69 (User 69) local loss: 0.7707
#   Client 70 (User 70) local loss: 0.7043
#   Client 71 (User 71) local loss: 0.6508
#   Client 72 (User 72) local loss: 0.6717
#   Client 73 (User 73) local loss: 0.7314
#   Client 74 (User 74) local loss: 0.6907
#   Client 75 (User 75) local loss: 0.6621
#   Client 76 (User 76) local loss: 0.7459
#   Client 77 (User 77) local loss: 0.6782
#   Client 78 (User 78) local loss: 0.6844
#   Client 79 (User 79) local loss: 0.7543
#   Client 80 (User 80) local loss: 0.7446
#   Client 81 (User 81) local loss: 0.6969
#   Client 82 (User 82) local loss: 0.7387
#   Client 83 (User 83) local loss: 0.6703
#   Client 84 (User 84) local loss: 0.7807
#   Client 85 (User 85) local loss: 0.7279
#   Client 86 (User 86) local loss: 0.6448
#   Client 87 (User 87) local loss: 0.6493
#   Client 88 (User 88) local loss: 0.6996
#   Client 89 (User 89) local loss: 0.6282
#   Client 90 (User 90) local loss: 0.7417
#   Client 91 (User 91) local loss: 0.6752
#   Client 92 (User 92) local loss: 0.7278
#   Client 93 (User 93) local loss: 0.6867
#   Client 94 (User 94) local loss: 0.6952
#   Client 95 (User 95) local loss: 0.7301
#   Client 96 (User 96) local loss: 0.6858
#   Client 97 (User 97) local loss: 0.7108
#   Client 98 (User 98) local loss: 0.6950
#   Client 99 (User 99) local loss: 0.6799
# Round 1 completed. Global item embeddings updated.
#
# --- Communication Round 2/10 ---
#   Client 0 (User 0) local loss: 0.6747
#   Client 1 (User 1) local loss: 0.7675
#   Client 2 (User 2) local loss: 0.7635
#   Client 3 (User 3) local loss: 0.6790
#   Client 4 (User 4) local loss: 0.7034
#   Client 5 (User 5) local loss: 0.6954
#   Client 6 (User 6) local loss: 0.7551
#   Client 7 (User 7) local loss: 0.7489
#   Client 8 (User 8) local loss: 0.6269
#   Client 9 (User 9) local loss: 0.6587
#   Client 10 (User 10) local loss: 0.6723
#   Client 11 (User 11) local loss: 0.6938
#   Client 12 (User 12) local loss: 0.6971
#   Client 13 (User 13) local loss: 0.6802
#   Client 14 (User 14) local loss: 0.6390
#   Client 15 (User 15) local loss: 0.7448
#   Client 16 (User 16) local loss: 0.8036
#   Client 17 (User 17) local loss: 0.6653
#   Client 18 (User 18) local loss: 0.7204
#   Client 19 (User 19) local loss: 0.6633
#   Client 20 (User 20) local loss: 0.6535
#   Client 21 (User 21) local loss: 0.7349
#   Client 22 (User 22) local loss: 0.6177
#   Client 23 (User 23) local loss: 0.7189
#   Client 24 (User 24) local loss: 0.7332
#   Client 25 (User 25) local loss: 0.6804
#   Client 26 (User 26) local loss: 0.6705
#   Client 27 (User 27) local loss: 0.6989
#   Client 28 (User 28) local loss: 0.6706
#   Client 29 (User 29) local loss: 0.7085
#   Client 30 (User 30) local loss: 0.7115
#   Client 31 (User 31) local loss: 0.6247
#   Client 32 (User 32) local loss: 0.6642
#   Client 33 (User 33) local loss: 0.6482
#   Client 34 (User 34) local loss: 0.7044
#   Client 35 (User 35) local loss: 0.7470
#   Client 36 (User 36) local loss: 0.6994
#   Client 37 (User 37) local loss: 0.7124
#   Client 38 (User 38) local loss: 0.6656
#   Client 39 (User 39) local loss: 0.6895
#   Client 40 (User 40) local loss: 0.6693
#   Client 41 (User 41) local loss: 0.6967
#   Client 42 (User 42) local loss: 0.6871
#   Client 43 (User 43) local loss: 0.6292
#   Client 44 (User 44) local loss: 0.7056
#   Client 45 (User 45) local loss: 0.6496
#   Client 46 (User 46) local loss: 0.6735
#   Client 47 (User 47) local loss: 0.7108
#   Client 48 (User 48) local loss: 0.6431
#   Client 49 (User 49) local loss: 0.7283
#   Client 50 (User 50) local loss: 0.7431
#   Client 51 (User 51) local loss: 0.7733
#   Client 52 (User 52) local loss: 0.6654
#   Client 53 (User 53) local loss: 0.7644
#   Client 54 (User 54) local loss: 0.7286
#   Client 55 (User 55) local loss: 0.6703
#   Client 56 (User 56) local loss: 0.6663
#   Client 57 (User 57) local loss: 0.7697
#   Client 58 (User 58) local loss: 0.6140
#   Client 59 (User 59) local loss: 0.6895
#   Client 60 (User 60) local loss: 0.6216
#   Client 61 (User 61) local loss: 0.6913
#   Client 62 (User 62) local loss: 0.7581
#   Client 63 (User 63) local loss: 0.6843
#   Client 64 (User 64) local loss: 0.7093
#   Client 65 (User 65) local loss: 0.7229
#   Client 66 (User 66) local loss: 0.7119
#   Client 67 (User 67) local loss: 0.7189
#   Client 68 (User 68) local loss: 0.7246
#   Client 69 (User 69) local loss: 0.7737
#   Client 70 (User 70) local loss: 0.7016
#   Client 71 (User 71) local loss: 0.6548
#   Client 72 (User 72) local loss: 0.6577
#   Client 73 (User 73) local loss: 0.7280
#   Client 74 (User 74) local loss: 0.6875
#   Client 75 (User 75) local loss: 0.6525
#   Client 76 (User 76) local loss: 0.7402
#   Client 77 (User 77) local loss: 0.6739
#   Client 78 (User 78) local loss: 0.6765
#   Client 79 (User 79) local loss: 0.7617
#   Client 80 (User 80) local loss: 0.7441
#   Client 81 (User 81) local loss: 0.6932
#   Client 82 (User 82) local loss: 0.7260
#   Client 83 (User 83) local loss: 0.6779
#   Client 84 (User 84) local loss: 0.7702
#   Client 85 (User 85) local loss: 0.7248
#   Client 86 (User 86) local loss: 0.6235
#   Client 87 (User 87) local loss: 0.6533
#   Client 88 (User 88) local loss: 0.6913
#   Client 89 (User 89) local loss: 0.6353
#   Client 90 (User 90) local loss: 0.7366
#   Client 91 (User 91) local loss: 0.6684
#   Client 92 (User 92) local loss: 0.7151
#   Client 93 (User 93) local loss: 0.6844
#   Client 94 (User 94) local loss: 0.6908
#   Client 95 (User 95) local loss: 0.7283
#   Client 96 (User 96) local loss: 0.6813
#   Client 97 (User 97) local loss: 0.7067
#   Client 98 (User 98) local loss: 0.6902
#   Client 99 (User 99) local loss: 0.6790
# Round 2 completed. Global item embeddings updated.
#
# --- Communication Round 3/10 ---
#   Client 0 (User 0) local loss: 0.6735
#   Client 1 (User 1) local loss: 0.7592
#   Client 2 (User 2) local loss: 0.7700
#   Client 3 (User 3) local loss: 0.6779
#   Client 4 (User 4) local loss: 0.6989
#   Client 5 (User 5) local loss: 0.6893
#   Client 6 (User 6) local loss: 0.7502
#   Client 7 (User 7) local loss: 0.7531
#   Client 8 (User 8) local loss: 0.6144
#   Client 9 (User 9) local loss: 0.6466
#   Client 10 (User 10) local loss: 0.6684
#   Client 11 (User 11) local loss: 0.6884
#   Client 12 (User 12) local loss: 0.6958
#   Client 13 (User 13) local loss: 0.6779
#   Client 14 (User 14) local loss: 0.6290
#   Client 15 (User 15) local loss: 0.7392
#   Client 16 (User 16) local loss: 0.8174
#   Client 17 (User 17) local loss: 0.6604
#   Client 18 (User 18) local loss: 0.7079
#   Client 19 (User 19) local loss: 0.6595
#   Client 20 (User 20) local loss: 0.6433
#   Client 21 (User 21) local loss: 0.7333
#   Client 22 (User 22) local loss: 0.6312
#   Client 23 (User 23) local loss: 0.7151
#   Client 24 (User 24) local loss: 0.7208
#   Client 25 (User 25) local loss: 0.6774
#   Client 26 (User 26) local loss: 0.6641
#   Client 27 (User 27) local loss: 0.6914
#   Client 28 (User 28) local loss: 0.6647
#   Client 29 (User 29) local loss: 0.7079
#   Client 30 (User 30) local loss: 0.7113
#   Client 31 (User 31) local loss: 0.6320
#   Client 32 (User 32) local loss: 0.6600
#   Client 33 (User 33) local loss: 0.6390
#   Client 34 (User 34) local loss: 0.7011
#   Client 35 (User 35) local loss: 0.7447
#   Client 36 (User 36) local loss: 0.6970
#   Client 37 (User 37) local loss: 0.7256
#   Client 38 (User 38) local loss: 0.6583
#   Client 39 (User 39) local loss: 0.6871
#   Client 40 (User 40) local loss: 0.6596
#   Client 41 (User 41) local loss: 0.6953
#   Client 42 (User 42) local loss: 0.6853
#   Client 43 (User 43) local loss: 0.6292
#   Client 44 (User 44) local loss: 0.6983
#   Client 45 (User 45) local loss: 0.6412
#   Client 46 (User 46) local loss: 0.6751
#   Client 47 (User 47) local loss: 0.7054
#   Client 48 (User 48) local loss: 0.6335
#   Client 49 (User 49) local loss: 0.7219
#   Client 50 (User 50) local loss: 0.7373
#   Client 51 (User 51) local loss: 0.7475
#   Client 52 (User 52) local loss: 0.6557
#   Client 53 (User 53) local loss: 0.7517
#   Client 54 (User 54) local loss: 0.7177
#   Client 55 (User 55) local loss: 0.6706
#   Client 56 (User 56) local loss: 0.6593
#   Client 57 (User 57) local loss: 0.7422
#   Client 58 (User 58) local loss: 0.6174
#   Client 59 (User 59) local loss: 0.6853
#   Client 60 (User 60) local loss: 0.6091
#   Client 61 (User 61) local loss: 0.6855
#   Client 62 (User 62) local loss: 0.7530
#   Client 63 (User 63) local loss: 0.6855
#   Client 64 (User 64) local loss: 0.7019
#   Client 65 (User 65) local loss: 0.7138
#   Client 66 (User 66) local loss: 0.7041
#   Client 67 (User 67) local loss: 0.7138
#   Client 68 (User 68) local loss: 0.7082
#   Client 69 (User 69) local loss: 0.7661
#   Client 70 (User 70) local loss: 0.7009
#   Client 71 (User 71) local loss: 0.6410
#   Client 72 (User 72) local loss: 0.6623
#   Client 73 (User 73) local loss: 0.7170
#   Client 74 (User 74) local loss: 0.6809
#   Client 75 (User 75) local loss: 0.6537
#   Client 76 (User 76) local loss: 0.7346
#   Client 77 (User 77) local loss: 0.6740
#   Client 78 (User 78) local loss: 0.6663
#   Client 79 (User 79) local loss: 0.7470
#   Client 80 (User 80) local loss: 0.7432
#   Client 81 (User 81) local loss: 0.6883
#   Client 82 (User 82) local loss: 0.7181
#   Client 83 (User 83) local loss: 0.6700
#   Client 84 (User 84) local loss: 0.7518
#   Client 85 (User 85) local loss: 0.7187
#   Client 86 (User 86) local loss: 0.6278
#   Client 87 (User 87) local loss: 0.6465
#   Client 88 (User 88) local loss: 0.6891
#   Client 89 (User 89) local loss: 0.6369
#   Client 90 (User 90) local loss: 0.7293
#   Client 91 (User 91) local loss: 0.6595
#   Client 92 (User 92) local loss: 0.7053
#   Client 93 (User 93) local loss: 0.6825
#   Client 94 (User 94) local loss: 0.6866
#   Client 95 (User 95) local loss: 0.7179
#   Client 96 (User 96) local loss: 0.6851
#   Client 97 (User 97) local loss: 0.7026
#   Client 98 (User 98) local loss: 0.6806
#   Client 99 (User 99) local loss: 0.6710
# Round 3 completed. Global item embeddings updated.
#
# --- Communication Round 4/10 ---
#   Client 0 (User 0) local loss: 0.6656
#   Client 1 (User 1) local loss: 0.7603
#   Client 2 (User 2) local loss: 0.7601
#   Client 3 (User 3) local loss: 0.6691
#   Client 4 (User 4) local loss: 0.6978
#   Client 5 (User 5) local loss: 0.6824
#   Client 6 (User 6) local loss: 0.7441
#   Client 7 (User 7) local loss: 0.7517
#   Client 8 (User 8) local loss: 0.6163
#   Client 9 (User 9) local loss: 0.6535
#   Client 10 (User 10) local loss: 0.6686
#   Client 11 (User 11) local loss: 0.6789
#   Client 12 (User 12) local loss: 0.6944
#   Client 13 (User 13) local loss: 0.6770
#   Client 14 (User 14) local loss: 0.6268
#   Client 15 (User 15) local loss: 0.7323
#   Client 16 (User 16) local loss: 0.7872
#   Client 17 (User 17) local loss: 0.6526
#   Client 18 (User 18) local loss: 0.7001
#   Client 19 (User 19) local loss: 0.6491
#   Client 20 (User 20) local loss: 0.6294
#   Client 21 (User 21) local loss: 0.7287
#   Client 22 (User 22) local loss: 0.6274
#   Client 23 (User 23) local loss: 0.7102
#   Client 24 (User 24) local loss: 0.7067
#   Client 25 (User 25) local loss: 0.6677
#   Client 26 (User 26) local loss: 0.6644
#   Client 27 (User 27) local loss: 0.6865
#   Client 28 (User 28) local loss: 0.6561
#   Client 29 (User 29) local loss: 0.7042
#   Client 30 (User 30) local loss: 0.7056
#   Client 31 (User 31) local loss: 0.6149
#   Client 32 (User 32) local loss: 0.6571
#   Client 33 (User 33) local loss: 0.6357
#   Client 34 (User 34) local loss: 0.6912
#   Client 35 (User 35) local loss: 0.7343
#   Client 36 (User 36) local loss: 0.6984
#   Client 37 (User 37) local loss: 0.7192
#   Client 38 (User 38) local loss: 0.6498
#   Client 39 (User 39) local loss: 0.6837
#   Client 40 (User 40) local loss: 0.6516
#   Client 41 (User 41) local loss: 0.6914
#   Client 42 (User 42) local loss: 0.6799
#   Client 43 (User 43) local loss: 0.6130
#   Client 44 (User 44) local loss: 0.6849
#   Client 45 (User 45) local loss: 0.6423
#   Client 46 (User 46) local loss: 0.6685
#   Client 47 (User 47) local loss: 0.7050
#   Client 48 (User 48) local loss: 0.6406
#   Client 49 (User 49) local loss: 0.7164
#   Client 50 (User 50) local loss: 0.7317
#   Client 51 (User 51) local loss: 0.7464
#   Client 52 (User 52) local loss: 0.6530
#   Client 53 (User 53) local loss: 0.7381
#   Client 54 (User 54) local loss: 0.7170
#   Client 55 (User 55) local loss: 0.6679
#   Client 56 (User 56) local loss: 0.6484
#   Client 57 (User 57) local loss: 0.7513
#   Client 58 (User 58) local loss: 0.5984
#   Client 59 (User 59) local loss: 0.6829
#   Client 60 (User 60) local loss: 0.6018
#   Client 61 (User 61) local loss: 0.6840
#   Client 62 (User 62) local loss: 0.7552
#   Client 63 (User 63) local loss: 0.6825
#   Client 64 (User 64) local loss: 0.6977
#   Client 65 (User 65) local loss: 0.7074
#   Client 66 (User 66) local loss: 0.6977
#   Client 67 (User 67) local loss: 0.7115
#   Client 68 (User 68) local loss: 0.6928
#   Client 69 (User 69) local loss: 0.7621
#   Client 70 (User 70) local loss: 0.6996
#   Client 71 (User 71) local loss: 0.6387
#   Client 72 (User 72) local loss: 0.6657
#   Client 73 (User 73) local loss: 0.7167
#   Client 74 (User 74) local loss: 0.6773
#   Client 75 (User 75) local loss: 0.6492
#   Client 76 (User 76) local loss: 0.7198
#   Client 77 (User 77) local loss: 0.6643
#   Client 78 (User 78) local loss: 0.6695
#   Client 79 (User 79) local loss: 0.7421
#   Client 80 (User 80) local loss: 0.7308
#   Client 81 (User 81) local loss: 0.6814
#   Client 82 (User 82) local loss: 0.7151
#   Client 83 (User 83) local loss: 0.6677
#   Client 84 (User 84) local loss: 0.7458
#   Client 85 (User 85) local loss: 0.7120
#   Client 86 (User 86) local loss: 0.6231
#   Client 87 (User 87) local loss: 0.6247
#   Client 88 (User 88) local loss: 0.6838
#   Client 89 (User 89) local loss: 0.6301
#   Client 90 (User 90) local loss: 0.7244
#   Client 91 (User 91) local loss: 0.6595
#   Client 92 (User 92) local loss: 0.6932
#   Client 93 (User 93) local loss: 0.6766
#   Client 94 (User 94) local loss: 0.6855
#   Client 95 (User 95) local loss: 0.7085
#   Client 96 (User 96) local loss: 0.6661
#   Client 97 (User 97) local loss: 0.7012
#   Client 98 (User 98) local loss: 0.6714
#   Client 99 (User 99) local loss: 0.6692
# Round 4 completed. Global item embeddings updated.
#
# --- Communication Round 5/10 ---
#   Client 0 (User 0) local loss: 0.6624
#   Client 1 (User 1) local loss: 0.7467
#   Client 2 (User 2) local loss: 0.7555
#   Client 3 (User 3) local loss: 0.6736
#   Client 4 (User 4) local loss: 0.6925
#   Client 5 (User 5) local loss: 0.6731
#   Client 6 (User 6) local loss: 0.7347
#   Client 7 (User 7) local loss: 0.7445
#   Client 8 (User 8) local loss: 0.6053
#   Client 9 (User 9) local loss: 0.6368
#   Client 10 (User 10) local loss: 0.6635
#   Client 11 (User 11) local loss: 0.6713
#   Client 12 (User 12) local loss: 0.6921
#   Client 13 (User 13) local loss: 0.6763
#   Client 14 (User 14) local loss: 0.6196
#   Client 15 (User 15) local loss: 0.7236
#   Client 16 (User 16) local loss: 0.7636
#   Client 17 (User 17) local loss: 0.6512
#   Client 18 (User 18) local loss: 0.6915
#   Client 19 (User 19) local loss: 0.6432
#   Client 20 (User 20) local loss: 0.6353
#   Client 21 (User 21) local loss: 0.7157
#   Client 22 (User 22) local loss: 0.6153
#   Client 23 (User 23) local loss: 0.7031
#   Client 24 (User 24) local loss: 0.6939
#   Client 25 (User 25) local loss: 0.6679
#   Client 26 (User 26) local loss: 0.6552
#   Client 27 (User 27) local loss: 0.6839
#   Client 28 (User 28) local loss: 0.6516
#   Client 29 (User 29) local loss: 0.6987
#   Client 30 (User 30) local loss: 0.7044
#   Client 31 (User 31) local loss: 0.6193
#   Client 32 (User 32) local loss: 0.6547
#   Client 33 (User 33) local loss: 0.6431
#   Client 34 (User 34) local loss: 0.6862
#   Client 35 (User 35) local loss: 0.7205
#   Client 36 (User 36) local loss: 0.6965
#   Client 37 (User 37) local loss: 0.7167
#   Client 38 (User 38) local loss: 0.6425
#   Client 39 (User 39) local loss: 0.6781
#   Client 40 (User 40) local loss: 0.6392
#   Client 41 (User 41) local loss: 0.6907
#   Client 42 (User 42) local loss: 0.6782
#   Client 43 (User 43) local loss: 0.5957
#   Client 44 (User 44) local loss: 0.6776
#   Client 45 (User 45) local loss: 0.6294
#   Client 46 (User 46) local loss: 0.6569
#   Client 47 (User 47) local loss: 0.7013
#   Client 48 (User 48) local loss: 0.6287
#   Client 49 (User 49) local loss: 0.7064
#   Client 50 (User 50) local loss: 0.7137
#   Client 51 (User 51) local loss: 0.7438
#   Client 52 (User 52) local loss: 0.6603
#   Client 53 (User 53) local loss: 0.7324
#   Client 54 (User 54) local loss: 0.7054
#   Client 55 (User 55) local loss: 0.6634
#   Client 56 (User 56) local loss: 0.6476
#   Client 57 (User 57) local loss: 0.7317
#   Client 58 (User 58) local loss: 0.6114
#   Client 59 (User 59) local loss: 0.6759
#   Client 60 (User 60) local loss: 0.6095
#   Client 61 (User 61) local loss: 0.6813
#   Client 62 (User 62) local loss: 0.7460
#   Client 63 (User 63) local loss: 0.6794
#   Client 64 (User 64) local loss: 0.6899
#   Client 65 (User 65) local loss: 0.7020
#   Client 66 (User 66) local loss: 0.6939
#   Client 67 (User 67) local loss: 0.7094
#   Client 68 (User 68) local loss: 0.6690
#   Client 69 (User 69) local loss: 0.7644
#   Client 70 (User 70) local loss: 0.6987
#   Client 71 (User 71) local loss: 0.6464
#   Client 72 (User 72) local loss: 0.6577
#   Client 73 (User 73) local loss: 0.7150
#   Client 74 (User 74) local loss: 0.6761
#   Client 75 (User 75) local loss: 0.6480
#   Client 76 (User 76) local loss: 0.7070
#   Client 77 (User 77) local loss: 0.6640
#   Client 78 (User 78) local loss: 0.6629
#   Client 79 (User 79) local loss: 0.7360
#   Client 80 (User 80) local loss: 0.7300
#   Client 81 (User 81) local loss: 0.6725
#   Client 82 (User 82) local loss: 0.7104
#   Client 83 (User 83) local loss: 0.6688
#   Client 84 (User 84) local loss: 0.7372
#   Client 85 (User 85) local loss: 0.7086
#   Client 86 (User 86) local loss: 0.6201
#   Client 87 (User 87) local loss: 0.6280
#   Client 88 (User 88) local loss: 0.6809
#   Client 89 (User 89) local loss: 0.6180
#   Client 90 (User 90) local loss: 0.7177
#   Client 91 (User 91) local loss: 0.6529
#   Client 92 (User 92) local loss: 0.6821
#   Client 93 (User 93) local loss: 0.6782
#   Client 94 (User 94) local loss: 0.6817
#   Client 95 (User 95) local loss: 0.7026
#   Client 96 (User 96) local loss: 0.6774
#   Client 97 (User 97) local loss: 0.6982
#   Client 98 (User 98) local loss: 0.6674
#   Client 99 (User 99) local loss: 0.6694
# Round 5 completed. Global item embeddings updated.
#
# --- Communication Round 6/10 ---
#   Client 0 (User 0) local loss: 0.6559
#   Client 1 (User 1) local loss: 0.7375
#   Client 2 (User 2) local loss: 0.7541
#   Client 3 (User 3) local loss: 0.6705
#   Client 4 (User 4) local loss: 0.6896
#   Client 5 (User 5) local loss: 0.6655
#   Client 6 (User 6) local loss: 0.7264
#   Client 7 (User 7) local loss: 0.7431
#   Client 8 (User 8) local loss: 0.6081
#   Client 9 (User 9) local loss: 0.6470
#   Client 10 (User 10) local loss: 0.6692
#   Client 11 (User 11) local loss: 0.6538
#   Client 12 (User 12) local loss: 0.6896
#   Client 13 (User 13) local loss: 0.6669
#   Client 14 (User 14) local loss: 0.6164
#   Client 15 (User 15) local loss: 0.7151
#   Client 16 (User 16) local loss: 0.7453
#   Client 17 (User 17) local loss: 0.6431
#   Client 18 (User 18) local loss: 0.6816
#   Client 19 (User 19) local loss: 0.6500
#   Client 20 (User 20) local loss: 0.6381
#   Client 21 (User 21) local loss: 0.7140
#   Client 22 (User 22) local loss: 0.6166
#   Client 23 (User 23) local loss: 0.6971
#   Client 24 (User 24) local loss: 0.6806
#   Client 25 (User 25) local loss: 0.6563
#   Client 26 (User 26) local loss: 0.6527
#   Client 27 (User 27) local loss: 0.6666
#   Client 28 (User 28) local loss: 0.6333
#   Client 29 (User 29) local loss: 0.6957
#   Client 30 (User 30) local loss: 0.7059
#   Client 31 (User 31) local loss: 0.5977
#   Client 32 (User 32) local loss: 0.6409
#   Client 33 (User 33) local loss: 0.6085
#   Client 34 (User 34) local loss: 0.6748
#   Client 35 (User 35) local loss: 0.7089
#   Client 36 (User 36) local loss: 0.6944
#   Client 37 (User 37) local loss: 0.7111
#   Client 38 (User 38) local loss: 0.6316
#   Client 39 (User 39) local loss: 0.6758
#   Client 40 (User 40) local loss: 0.6230
#   Client 41 (User 41) local loss: 0.6875
#   Client 42 (User 42) local loss: 0.6745
#   Client 43 (User 43) local loss: 0.6138
#   Client 44 (User 44) local loss: 0.6614
#   Client 45 (User 45) local loss: 0.6252
#   Client 46 (User 46) local loss: 0.6661
#   Client 47 (User 47) local loss: 0.6947
#   Client 48 (User 48) local loss: 0.6270
#   Client 49 (User 49) local loss: 0.7014
#   Client 50 (User 50) local loss: 0.6998
#   Client 51 (User 51) local loss: 0.7288
#   Client 52 (User 52) local loss: 0.6562
#   Client 53 (User 53) local loss: 0.7182
#   Client 54 (User 54) local loss: 0.7011
#   Client 55 (User 55) local loss: 0.6560
#   Client 56 (User 56) local loss: 0.6383
#   Client 57 (User 57) local loss: 0.7285
#   Client 58 (User 58) local loss: 0.6026
#   Client 59 (User 59) local loss: 0.6676
#   Client 60 (User 60) local loss: 0.5796
#   Client 61 (User 61) local loss: 0.6715
#   Client 62 (User 62) local loss: 0.7349
#   Client 63 (User 63) local loss: 0.6755
#   Client 64 (User 64) local loss: 0.6789
#   Client 65 (User 65) local loss: 0.6959
#   Client 66 (User 66) local loss: 0.6869
#   Client 67 (User 67) local loss: 0.7005
#   Client 68 (User 68) local loss: 0.6459
#   Client 69 (User 69) local loss: 0.7555
#   Client 70 (User 70) local loss: 0.6968
#   Client 71 (User 71) local loss: 0.6367
#   Client 72 (User 72) local loss: 0.6473
#   Client 73 (User 73) local loss: 0.7080
#   Client 74 (User 74) local loss: 0.6713
#   Client 75 (User 75) local loss: 0.6328
#   Client 76 (User 76) local loss: 0.6939
#   Client 77 (User 77) local loss: 0.6542
#   Client 78 (User 78) local loss: 0.6640
#   Client 79 (User 79) local loss: 0.7287
#   Client 80 (User 80) local loss: 0.7240
#   Client 81 (User 81) local loss: 0.6630
#   Client 82 (User 82) local loss: 0.7072
#   Client 83 (User 83) local loss: 0.6602
#   Client 84 (User 84) local loss: 0.7169
#   Client 85 (User 85) local loss: 0.7041
#   Client 86 (User 86) local loss: 0.6067
#   Client 87 (User 87) local loss: 0.6173
#   Client 88 (User 88) local loss: 0.6748
#   Client 89 (User 89) local loss: 0.5996
#   Client 90 (User 90) local loss: 0.7139
#   Client 91 (User 91) local loss: 0.6449
#   Client 92 (User 92) local loss: 0.6677
#   Client 93 (User 93) local loss: 0.6746
#   Client 94 (User 94) local loss: 0.6795
#   Client 95 (User 95) local loss: 0.6913
#   Client 96 (User 96) local loss: 0.6827
#   Client 97 (User 97) local loss: 0.6935
#   Client 98 (User 98) local loss: 0.6607
#   Client 99 (User 99) local loss: 0.6682
# Round 6 completed. Global item embeddings updated.
#
# --- Communication Round 7/10 ---
#   Client 0 (User 0) local loss: 0.6513
#   Client 1 (User 1) local loss: 0.7326
#   Client 2 (User 2) local loss: 0.7460
#   Client 3 (User 3) local loss: 0.6666
#   Client 4 (User 4) local loss: 0.6849
#   Client 5 (User 5) local loss: 0.6521
#   Client 6 (User 6) local loss: 0.7132
#   Client 7 (User 7) local loss: 0.7413
#   Client 8 (User 8) local loss: 0.5939
#   Client 9 (User 9) local loss: 0.6431
#   Client 10 (User 10) local loss: 0.6525
#   Client 11 (User 11) local loss: 0.6375
#   Client 12 (User 12) local loss: 0.6871
#   Client 13 (User 13) local loss: 0.6683
#   Client 14 (User 14) local loss: 0.5943
#   Client 15 (User 15) local loss: 0.7013
#   Client 16 (User 16) local loss: 0.7138
#   Client 17 (User 17) local loss: 0.6366
#   Client 18 (User 18) local loss: 0.6703
#   Client 19 (User 19) local loss: 0.6513
#   Client 20 (User 20) local loss: 0.6195
#   Client 21 (User 21) local loss: 0.7028
#   Client 22 (User 22) local loss: 0.5978
#   Client 23 (User 23) local loss: 0.6895
#   Client 24 (User 24) local loss: 0.6636
#   Client 25 (User 25) local loss: 0.6433
#   Client 26 (User 26) local loss: 0.6545
#   Client 27 (User 27) local loss: 0.6655
#   Client 28 (User 28) local loss: 0.6016
#   Client 29 (User 29) local loss: 0.6948
#   Client 30 (User 30) local loss: 0.7047
#   Client 31 (User 31) local loss: 0.6022
#   Client 32 (User 32) local loss: 0.6499
#   Client 33 (User 33) local loss: 0.6105
#   Client 34 (User 34) local loss: 0.6730
#   Client 35 (User 35) local loss: 0.6949
#   Client 36 (User 36) local loss: 0.6937
#   Client 37 (User 37) local loss: 0.7142
#   Client 38 (User 38) local loss: 0.6202
#   Client 39 (User 39) local loss: 0.6629
#   Client 40 (User 40) local loss: 0.6212
#   Client 41 (User 41) local loss: 0.6845
#   Client 42 (User 42) local loss: 0.6751
#   Client 43 (User 43) local loss: 0.6077
#   Client 44 (User 44) local loss: 0.6504
#   Client 45 (User 45) local loss: 0.6110
#   Client 46 (User 46) local loss: 0.6640
#   Client 47 (User 47) local loss: 0.6923
#   Client 48 (User 48) local loss: 0.6146
#   Client 49 (User 49) local loss: 0.6955
#   Client 50 (User 50) local loss: 0.6818
#   Client 51 (User 51) local loss: 0.7075
#   Client 52 (User 52) local loss: 0.6544
#   Client 53 (User 53) local loss: 0.7129
#   Client 54 (User 54) local loss: 0.6913
#   Client 55 (User 55) local loss: 0.6528
#   Client 56 (User 56) local loss: 0.6452
#   Client 57 (User 57) local loss: 0.7139
#   Client 58 (User 58) local loss: 0.5919
#   Client 59 (User 59) local loss: 0.6560
#   Client 60 (User 60) local loss: 0.5821
#   Client 61 (User 61) local loss: 0.6770
#   Client 62 (User 62) local loss: 0.7305
#   Client 63 (User 63) local loss: 0.6700
#   Client 64 (User 64) local loss: 0.6673
#   Client 65 (User 65) local loss: 0.6876
#   Client 66 (User 66) local loss: 0.6808
#   Client 67 (User 67) local loss: 0.6947
#   Client 68 (User 68) local loss: 0.6059
#   Client 69 (User 69) local loss: 0.7480
#   Client 70 (User 70) local loss: 0.6960
#   Client 71 (User 71) local loss: 0.6185
#   Client 72 (User 72) local loss: 0.6384
#   Client 73 (User 73) local loss: 0.7046
#   Client 74 (User 74) local loss: 0.6664
#   Client 75 (User 75) local loss: 0.6421
#   Client 76 (User 76) local loss: 0.6657
#   Client 77 (User 77) local loss: 0.6494
#   Client 78 (User 78) local loss: 0.6620
#   Client 79 (User 79) local loss: 0.7198
#   Client 80 (User 80) local loss: 0.7258
#   Client 81 (User 81) local loss: 0.6462
#   Client 82 (User 82) local loss: 0.7042
#   Client 83 (User 83) local loss: 0.6678
#   Client 84 (User 84) local loss: 0.6953
#   Client 85 (User 85) local loss: 0.7005
#   Client 86 (User 86) local loss: 0.6023
#   Client 87 (User 87) local loss: 0.6410
#   Client 88 (User 88) local loss: 0.6742
#   Client 89 (User 89) local loss: 0.5977
#   Client 90 (User 90) local loss: 0.7118
#   Client 91 (User 91) local loss: 0.6353
#   Client 92 (User 92) local loss: 0.6397
#   Client 93 (User 93) local loss: 0.6747
#   Client 94 (User 94) local loss: 0.6753
#   Client 95 (User 95) local loss: 0.6767
#   Client 96 (User 96) local loss: 0.6816
#   Client 97 (User 97) local loss: 0.6894
#   Client 98 (User 98) local loss: 0.6431
#   Client 99 (User 99) local loss: 0.6623
# Round 7 completed. Global item embeddings updated.
#
# --- Communication Round 8/10 ---
#   Client 0 (User 0) local loss: 0.6489
#   Client 1 (User 1) local loss: 0.7120
#   Client 2 (User 2) local loss: 0.7364
#   Client 3 (User 3) local loss: 0.6702
#   Client 4 (User 4) local loss: 0.6841
#   Client 5 (User 5) local loss: 0.6267
#   Client 6 (User 6) local loss: 0.6986
#   Client 7 (User 7) local loss: 0.7364
#   Client 8 (User 8) local loss: 0.5859
#   Client 9 (User 9) local loss: 0.6285
#   Client 10 (User 10) local loss: 0.6560
#   Client 11 (User 11) local loss: 0.6224
#   Client 12 (User 12) local loss: 0.6837
#   Client 13 (User 13) local loss: 0.6617
#   Client 14 (User 14) local loss: 0.5885
#   Client 15 (User 15) local loss: 0.6875
#   Client 16 (User 16) local loss: 0.6899
#   Client 17 (User 17) local loss: 0.6332
#   Client 18 (User 18) local loss: 0.6546
#   Client 19 (User 19) local loss: 0.6422
#   Client 20 (User 20) local loss: 0.6116
#   Client 21 (User 21) local loss: 0.6931
#   Client 22 (User 22) local loss: 0.6173
#   Client 23 (User 23) local loss: 0.6760
#   Client 24 (User 24) local loss: 0.6441
#   Client 25 (User 25) local loss: 0.6394
#   Client 26 (User 26) local loss: 0.6454
#   Client 27 (User 27) local loss: 0.6642
#   Client 28 (User 28) local loss: 0.6074
#   Client 29 (User 29) local loss: 0.6911
#   Client 30 (User 30) local loss: 0.7011
#   Client 31 (User 31) local loss: 0.5914
#   Client 32 (User 32) local loss: 0.6425
#   Client 33 (User 33) local loss: 0.6480
#   Client 34 (User 34) local loss: 0.6662
#   Client 35 (User 35) local loss: 0.6792
#   Client 36 (User 36) local loss: 0.6944
#   Client 37 (User 37) local loss: 0.7105
#   Client 38 (User 38) local loss: 0.5949
#   Client 39 (User 39) local loss: 0.6625
#   Client 40 (User 40) local loss: 0.5802
#   Client 41 (User 41) local loss: 0.6825
#   Client 42 (User 42) local loss: 0.6727
#   Client 43 (User 43) local loss: 0.6072
#   Client 44 (User 44) local loss: 0.6403
#   Client 45 (User 45) local loss: 0.5999
#   Client 46 (User 46) local loss: 0.6501
#   Client 47 (User 47) local loss: 0.6871
#   Client 48 (User 48) local loss: 0.5959
#   Client 49 (User 49) local loss: 0.6865
#   Client 50 (User 50) local loss: 0.6589
#   Client 51 (User 51) local loss: 0.6886
#   Client 52 (User 52) local loss: 0.6626
#   Client 53 (User 53) local loss: 0.7065
#   Client 54 (User 54) local loss: 0.6855
#   Client 55 (User 55) local loss: 0.6398
#   Client 56 (User 56) local loss: 0.6360
#   Client 57 (User 57) local loss: 0.7005
#   Client 58 (User 58) local loss: 0.5828
#   Client 59 (User 59) local loss: 0.6516
#   Client 60 (User 60) local loss: 0.5784
#   Client 61 (User 61) local loss: 0.6746
#   Client 62 (User 62) local loss: 0.7151
#   Client 63 (User 63) local loss: 0.6721
#   Client 64 (User 64) local loss: 0.6528
#   Client 65 (User 65) local loss: 0.6793
#   Client 66 (User 66) local loss: 0.6764
#   Client 67 (User 67) local loss: 0.6864
#   Client 68 (User 68) local loss: 0.5896
#   Client 69 (User 69) local loss: 0.7498
#   Client 70 (User 70) local loss: 0.6951
#   Client 71 (User 71) local loss: 0.6285
#   Client 72 (User 72) local loss: 0.6429
#   Client 73 (User 73) local loss: 0.7139
#   Client 74 (User 74) local loss: 0.6643
#   Client 75 (User 75) local loss: 0.6513
#   Client 76 (User 76) local loss: 0.6435
#   Client 77 (User 77) local loss: 0.6482
#   Client 78 (User 78) local loss: 0.6597
#   Client 79 (User 79) local loss: 0.7005
#   Client 80 (User 80) local loss: 0.7276
#   Client 81 (User 81) local loss: 0.6303
#   Client 82 (User 82) local loss: 0.6987
#   Client 83 (User 83) local loss: 0.6600
#   Client 84 (User 84) local loss: 0.6683
#   Client 85 (User 85) local loss: 0.6957
#   Client 86 (User 86) local loss: 0.6018
#   Client 87 (User 87) local loss: 0.6046
#   Client 88 (User 88) local loss: 0.6695
#   Client 89 (User 89) local loss: 0.6131
#   Client 90 (User 90) local loss: 0.7065
#   Client 91 (User 91) local loss: 0.6372
#   Client 92 (User 92) local loss: 0.6287
#   Client 93 (User 93) local loss: 0.6731
#   Client 94 (User 94) local loss: 0.6757
#   Client 95 (User 95) local loss: 0.6572
#   Client 96 (User 96) local loss: 0.6700
#   Client 97 (User 97) local loss: 0.6868
#   Client 98 (User 98) local loss: 0.6390
#   Client 99 (User 99) local loss: 0.6687
# Round 8 completed. Global item embeddings updated.
#
# --- Communication Round 9/10 ---
#   Client 0 (User 0) local loss: 0.6340
#   Client 1 (User 1) local loss: 0.6852
#   Client 2 (User 2) local loss: 0.7244
#   Client 3 (User 3) local loss: 0.6697
#   Client 4 (User 4) local loss: 0.6825
#   Client 5 (User 5) local loss: 0.6164
#   Client 6 (User 6) local loss: 0.6800
#   Client 7 (User 7) local loss: 0.7368
#   Client 8 (User 8) local loss: 0.5829
#   Client 9 (User 9) local loss: 0.6337
#   Client 10 (User 10) local loss: 0.6596
#   Client 11 (User 11) local loss: 0.5902
#   Client 12 (User 12) local loss: 0.6782
#   Client 13 (User 13) local loss: 0.6583
#   Client 14 (User 14) local loss: 0.5654
#   Client 15 (User 15) local loss: 0.6648
#   Client 16 (User 16) local loss: 0.6370
#   Client 17 (User 17) local loss: 0.6125
#   Client 18 (User 18) local loss: 0.6459
#   Client 19 (User 19) local loss: 0.6434
#   Client 20 (User 20) local loss: 0.6303
#   Client 21 (User 21) local loss: 0.6768
#   Client 22 (User 22) local loss: 0.6110
#   Client 23 (User 23) local loss: 0.6593
#   Client 24 (User 24) local loss: 0.6351
#   Client 25 (User 25) local loss: 0.6194
#   Client 26 (User 26) local loss: 0.6439
#   Client 27 (User 27) local loss: 0.6362
#   Client 28 (User 28) local loss: 0.5880
#   Client 29 (User 29) local loss: 0.6883
#   Client 30 (User 30) local loss: 0.7021
#   Client 31 (User 31) local loss: 0.6237
#   Client 32 (User 32) local loss: 0.6372
#   Client 33 (User 33) local loss: 0.6199
#   Client 34 (User 34) local loss: 0.6493
#   Client 35 (User 35) local loss: 0.6488
#   Client 36 (User 36) local loss: 0.6915
#   Client 37 (User 37) local loss: 0.7106
#   Client 38 (User 38) local loss: 0.5976
#   Client 39 (User 39) local loss: 0.6542
#   Client 40 (User 40) local loss: 0.5700
#   Client 41 (User 41) local loss: 0.6801
#   Client 42 (User 42) local loss: 0.6695
#   Client 43 (User 43) local loss: 0.5814
#   Client 44 (User 44) local loss: 0.6308
#   Client 45 (User 45) local loss: 0.5982
#   Client 46 (User 46) local loss: 0.6443
#   Client 47 (User 47) local loss: 0.6797
#   Client 48 (User 48) local loss: 0.6286
#   Client 49 (User 49) local loss: 0.6766
#   Client 50 (User 50) local loss: 0.6495
#   Client 51 (User 51) local loss: 0.6745
#   Client 52 (User 52) local loss: 0.6460
#   Client 53 (User 53) local loss: 0.6964
#   Client 54 (User 54) local loss: 0.6718
#   Client 55 (User 55) local loss: 0.6278
#   Client 56 (User 56) local loss: 0.6353
#   Client 57 (User 57) local loss: 0.6868
#   Client 58 (User 58) local loss: 0.5899
#   Client 59 (User 59) local loss: 0.6367
#   Client 60 (User 60) local loss: 0.5805
#   Client 61 (User 61) local loss: 0.6633
#   Client 62 (User 62) local loss: 0.7007
#   Client 63 (User 63) local loss: 0.6656
#   Client 64 (User 64) local loss: 0.6292
#   Client 65 (User 65) local loss: 0.6681
#   Client 66 (User 66) local loss: 0.6662
#   Client 67 (User 67) local loss: 0.6634
#   Client 68 (User 68) local loss: 0.5566
#   Client 69 (User 69) local loss: 0.7490
#   Client 70 (User 70) local loss: 0.6939
#   Client 71 (User 71) local loss: 0.6281
#   Client 72 (User 72) local loss: 0.6362
#   Client 73 (User 73) local loss: 0.7092
#   Client 74 (User 74) local loss: 0.6578
#   Client 75 (User 75) local loss: 0.6279
#   Client 76 (User 76) local loss: 0.6156
#   Client 77 (User 77) local loss: 0.6370
#   Client 78 (User 78) local loss: 0.6532
#   Client 79 (User 79) local loss: 0.6881
#   Client 80 (User 80) local loss: 0.7184
#   Client 81 (User 81) local loss: 0.6143
#   Client 82 (User 82) local loss: 0.6911
#   Client 83 (User 83) local loss: 0.6614
#   Client 84 (User 84) local loss: 0.6345
#   Client 85 (User 85) local loss: 0.6915
#   Client 86 (User 86) local loss: 0.5970
#   Client 87 (User 87) local loss: 0.6062
#   Client 88 (User 88) local loss: 0.6686
#   Client 89 (User 89) local loss: 0.6013
#   Client 90 (User 90) local loss: 0.7008
#   Client 91 (User 91) local loss: 0.6376
#   Client 92 (User 92) local loss: 0.6013
#   Client 93 (User 93) local loss: 0.6658
#   Client 94 (User 94) local loss: 0.6689
#   Client 95 (User 95) local loss: 0.6387
#   Client 96 (User 96) local loss: 0.6657
#   Client 97 (User 97) local loss: 0.6768
#   Client 98 (User 98) local loss: 0.6133
#   Client 99 (User 99) local loss: 0.6723
# Round 9 completed. Global item embeddings updated.
#
# --- Communication Round 10/10 ---
#   Client 0 (User 0) local loss: 0.6240
#   Client 1 (User 1) local loss: 0.6636
#   Client 2 (User 2) local loss: 0.7071
#   Client 3 (User 3) local loss: 0.6701
#   Client 4 (User 4) local loss: 0.6736
#   Client 5 (User 5) local loss: 0.5971
#   Client 6 (User 6) local loss: 0.6536
#   Client 7 (User 7) local loss: 0.7283
#   Client 8 (User 8) local loss: 0.5900
#   Client 9 (User 9) local loss: 0.6278
#   Client 10 (User 10) local loss: 0.6562
#   Client 11 (User 11) local loss: 0.5571
#   Client 12 (User 12) local loss: 0.6702
#   Client 13 (User 13) local loss: 0.6570
#   Client 14 (User 14) local loss: 0.5532
#   Client 15 (User 15) local loss: 0.6346
#   Client 16 (User 16) local loss: 0.5888
#   Client 17 (User 17) local loss: 0.6086
#   Client 18 (User 18) local loss: 0.6113
#   Client 19 (User 19) local loss: 0.6241
#   Client 20 (User 20) local loss: 0.6045
#   Client 21 (User 21) local loss: 0.6603
#   Client 22 (User 22) local loss: 0.6030
#   Client 23 (User 23) local loss: 0.6507
#   Client 24 (User 24) local loss: 0.5906
#   Client 25 (User 25) local loss: 0.6194
#   Client 26 (User 26) local loss: 0.6434
#   Client 27 (User 27) local loss: 0.6278
#   Client 28 (User 28) local loss: 0.5554
#   Client 29 (User 29) local loss: 0.6881
#   Client 30 (User 30) local loss: 0.7001
#   Client 31 (User 31) local loss: 0.5642
#   Client 32 (User 32) local loss: 0.6321
#   Client 33 (User 33) local loss: 0.6019
#   Client 34 (User 34) local loss: 0.6335
#   Client 35 (User 35) local loss: 0.6261
#   Client 36 (User 36) local loss: 0.6908
#   Client 37 (User 37) local loss: 0.7109
#   Client 38 (User 38) local loss: 0.5496
#   Client 39 (User 39) local loss: 0.6593
#   Client 40 (User 40) local loss: 0.5465
#   Client 41 (User 41) local loss: 0.6782
#   Client 42 (User 42) local loss: 0.6641
#   Client 43 (User 43) local loss: 0.5947
#   Client 44 (User 44) local loss: 0.6147
#   Client 45 (User 45) local loss: 0.5732
#   Client 46 (User 46) local loss: 0.6359
#   Client 47 (User 47) local loss: 0.6724
#   Client 48 (User 48) local loss: 0.6119
#   Client 49 (User 49) local loss: 0.6667
#   Client 50 (User 50) local loss: 0.6190
#   Client 51 (User 51) local loss: 0.6494
#   Client 52 (User 52) local loss: 0.6373
#   Client 53 (User 53) local loss: 0.6859
#   Client 54 (User 54) local loss: 0.6641
#   Client 55 (User 55) local loss: 0.6289
#   Client 56 (User 56) local loss: 0.6357
#   Client 57 (User 57) local loss: 0.6812
#   Client 58 (User 58) local loss: 0.5845
#   Client 59 (User 59) local loss: 0.6280
#   Client 60 (User 60) local loss: 0.5502
#   Client 61 (User 61) local loss: 0.6690
#   Client 62 (User 62) local loss: 0.6807
#   Client 63 (User 63) local loss: 0.6658
#   Client 64 (User 64) local loss: 0.6132
#   Client 65 (User 65) local loss: 0.6584
#   Client 66 (User 66) local loss: 0.6565
#   Client 67 (User 67) local loss: 0.6570
#   Client 68 (User 68) local loss: 0.5932
#   Client 69 (User 69) local loss: 0.7480
#   Client 70 (User 70) local loss: 0.6923
#   Client 71 (User 71) local loss: 0.5988
#   Client 72 (User 72) local loss: 0.6432
#   Client 73 (User 73) local loss: 0.7047
#   Client 74 (User 74) local loss: 0.6463
#   Client 75 (User 75) local loss: 0.6269
#   Client 76 (User 76) local loss: 0.5663
#   Client 77 (User 77) local loss: 0.6236
#   Client 78 (User 78) local loss: 0.6490
#   Client 79 (User 79) local loss: 0.6645
#   Client 80 (User 80) local loss: 0.7196
#   Client 81 (User 81) local loss: 0.6203
#   Client 82 (User 82) local loss: 0.6789
#   Client 83 (User 83) local loss: 0.6499
#   Client 84 (User 84) local loss: 0.6209
#   Client 85 (User 85) local loss: 0.6869
#   Client 86 (User 86) local loss: 0.5962
#   Client 87 (User 87) local loss: 0.6004
#   Client 88 (User 88) local loss: 0.6600
#   Client 89 (User 89) local loss: 0.6026
#   Client 90 (User 90) local loss: 0.6876
#   Client 91 (User 91) local loss: 0.6153
#   Client 92 (User 92) local loss: 0.5949
#   Client 93 (User 93) local loss: 0.6693
#   Client 94 (User 94) local loss: 0.6614
#   Client 95 (User 95) local loss: 0.6162
#   Client 96 (User 96) local loss: 0.6712
#   Client 97 (User 97) local loss: 0.6630
#   Client 98 (User 98) local loss: 0.6042
#   Client 99 (User 99) local loss: 0.6502
# Round 10 completed. Global item embeddings updated.
# Federated training completed.

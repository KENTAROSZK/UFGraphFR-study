# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Subset
from transformers import AutoModel, AutoTokenizer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# %% [markdown]
# ## 2. データセットの準備とクライアントへの分割

# %%
# データセットの準備とクライアントへの分割 (変更)
# 1クライアント1ユーザーをシミュレート
num_users = 100
num_items = 50
num_clients = num_users # クライアント数とユーザー数を同じにする

user_texts = {i: f"This user likes movies about {i % 5} and enjoys {i % 3}." for i in range(num_users)}

interactions_list = []
for u_id in range(num_users):
    for i_id in range(num_items):
        if np.random.rand() > 0.7:
            interactions_list.append([u_id, i_id, 1])
        else:
            interactions_list.append([u_id, i_id, 0])

interactions = torch.tensor(interactions_list, dtype=torch.float32)

client_user_map = {} # {client_id: user_id}
client_datasets = {}
for u_id in range(num_users):
    client_id = u_id # クライアントIDをユーザーIDと同じにする NOTE: 1クライアント複数ユーザのようなケースにも対応できるようにしているが今回は、1クライアント1ユーザ.
    client_user_map[client_id] = u_id

    # 各クライアントはそのユーザーのインタラクションデータのみを持つ
    client_interactions_indices = [item for item, (user, _, _) in enumerate(interactions_list) if user == u_id]
    client_subset = Subset(
        TensorDataset(interactions[:, 0].long(), interactions[:, 1].long(), interactions[:, 2]),
        client_interactions_indices
    )
    client_datasets[client_id] = DataLoader(client_subset, batch_size=10, shuffle=True)

# %% [markdown]
# ## 3. 軽量 LLM 埋め込みモデルのロード

# %%
# 軽量 LLM 埋め込みモデルのロード (変更なし)
plm_model_name = "sentence-transformers/all-MiniLM-L6-v2"
plm_tokenizer = AutoTokenizer.from_pretrained(plm_model_name)
plm_model = AutoModel.from_pretrained(plm_model_name)

# PLMは学習済みモデルのため、勾配計算を無効化
for param in plm_model.parameters():
    param.requires_grad = False

plm_embedding_dim = plm_model.config.hidden_size
print(f"PLM embedding dimension: {plm_embedding_dim}")
# Out:
# PLM embedding dimension: 384

# %% [markdown]
# ## 4. モデルの定義 (変更あり: グローバルアイテム埋め込みの追加)
# 各クライアントが持つモデルに加えて、サーバーが管理する「グローバルアイテム埋め込み」を導入します。これは、論文における
#
# theta_item に相当します 。

# %%
class ClientModel(nn.Module):
    def __init__(
        self,
        num_items,
        item_embedding_dim,
        plm_model,
        plm_embedding_dim,
        joint_embedding_output_dim
    ):
        super(ClientModel, self).__init__()
        self.plm_model = plm_model

        # Joint Embedding Layer の線形変換部分 (ユーザーのローカルパラメータ)
        # 論文の「trainable linear layer」[cite: 75]
        self.user_joint_embedding_linear = nn.Linear(plm_embedding_dim, joint_embedding_output_dim)

        # アイテム埋め込み (各クライアントのローカルパラメータとして初期化される)
        self.local_item_embedding = nn.Embedding(num_items, item_embedding_dim)

        # 予測層. 本来は、ここはMLPで3層になる予定だが、今回は、1層の単純線形層で出力する.
        self.prediction_layer = nn.Linear(joint_embedding_output_dim + item_embedding_dim, 1)

    def forward(self, item_ids, user_texts_batch):
        # ユーザーのテキスト特徴をPLMで埋め込み
        encoded_input = plm_tokenizer(user_texts_batch, padding=True, truncation=True, return_tensors='pt')
        plm_output = self.plm_model(**encoded_input).last_hidden_state[:, 0, :] # [CLS]トークンの埋め込みを使用 [cite: 73]

        # Joint Embedding Layer の線形変換
        # 論文の式(3): e_u = h(v_u) = v_u W_d1xd + b [cite: 78]
        user_embedding = self.user_joint_embedding_linear(plm_output)

        # ローカルのアイテム埋め込み
        item_embedding = self.local_item_embedding(item_ids)

        # ユーザー埋め込みとアイテム埋め込みを結合
        combined_features = torch.cat((user_embedding, item_embedding), dim=1)

        # 予測
        prediction = torch.sigmoid(self.prediction_layer(combined_features))
        # 論文では「user joint embedding weights」[cite: 61] と「local item embeddings」[cite: 61] をサーバーに送信するとある。
        # ここでは、user_joint_embedding_linear.weight と local_item_embedding.weight を返す
        return prediction, self.user_joint_embedding_linear.weight, self.local_item_embedding.weight

# %%
class Server:
    def __init__(
        self,
        num_users,
        num_items,
        item_embedding_dim,
        joint_embedding_output_dim,
    ):
        # グローバルアイテム埋め込みは、全アイテムの埋め込み行列として管理
        self.global_item_embedding = nn.Embedding(num_items, item_embedding_dim)
        self.num_users = num_users
        self.num_items = num_items
        self.item_embedding_dim = item_embedding_dim
        self.joint_embedding_output_dim = joint_embedding_output_dim

    def build_user_relationship_graph(
        self,
        user_linear_weights_map,
    ):
        """
        各ユーザーのuser_joint_embedding_linear.weightからユーザー関係グラフを構築します。
        論文の式 (15) に基づいています。

        Args:
            user_linear_weights_map (dict): {user_id: user_joint_embedding_linear.weight.data (flattened)}

        Returns:
            np.ndarray: ユーザーグラフの隣接行列 (NumPy配列)
            list: グラフのノード順に対応するユーザーIDのリスト
        """
        # ユーザIDをグラフのノードとして扱う
        sorted_user_ids = sorted(user_linear_weights_map.keys())

        # 各ユーザの線形層の重みベクトルを収集する.
        # 論文の「w_i = vec(W_i)」に相当 [cite: 105]
        # FIXME: 今は、クライアント側でやってしまっているが、行列をベクトル化するのは、サーバ側でやっておきたい.
        user_weight_vectors = np.array([
            user_linear_weights_map[u_id].cpu().numpy() for u_id in sorted_user_ids
        ])

        # cos類似度で類似度行列を計算(S_ij)
        # 論文の式(15)に相当 [cite: 106]
        similarity_matrix = cosine_similarity(user_weight_vectors)

        # 各ユーザーの上位N個の類似ユーザーを選択してグラフを構築 (ここでは簡単のため、全てのユーザー間の類似度を使用)
        # 論文のStep2では「top-N in the highest similarity list」とあるが [cite: 108]、
        # ここでは完全な類似度グラフ (隣接行列) を使用。
        # 厳密には、ここで閾値を設けるか、上位K個のみを選択して疎なグラフを構築すべき。
        # S' に相当 [cite: 108]
        user_graph_adj = similarity_matrix 

        return user_graph_adj, sorted_user_ids

    def aggregate_item_embeddings(
        self,
        user_local_item_weights,
        user_graph_adj,
        sorted_user_ids,
    ):
        """
        ユーザー関係グラフに基づいて、アイテム埋め込みをグローバルに集約します。
        論文の式 (16) と (17) に基づいています。

        Args:
            user_local_item_weights (dict): {user_id: local_item_embedding.weight.data (Tensor)}
            user_graph_adj (np.ndarray): ユーザーグラフの隣接行列
            sorted_user_ids (list): user_graph_adj のノード順に対応するユーザーIDのリスト

        Returns:
            torch.Tensor: 更新されたグローバルアイテム埋め込みの重み
        """
        # グラフの順序に合わせて各ユーザーのアイテム埋め込みを行列Aとしてまとめる
        # A は (num_users, num_items, item_embedding_dim)
        # 論文の「A is the round item embedding matrix, the I-th row represents the item embedding obtained from user i」に相当 
        item_embedding_matrix_A = torch.stack([
            user_local_item_weights[u_id] for u_id in sorted_user_ids
        ]) # (num_users, num_items, item_embedding_dim)

        # グラフの正規化 (S'')
        # NOTE: 正規化が必要な理由
        ### スケール調整と数値安定性: 隣接行列をそのまま使うと、ノードの次数（接続数）が大きいほど、そのノードから受け取る情報の合計が非常に大きくなってしまいます。これにより、特徴量のスケールが大きくなりすぎたり、訓練中に勾配爆発を引き起こしたりする可能性があります。正規化は、この影響を均一化し、数値的な安定性を確保するのに役立ちます 。
        ### 特徴量の平滑化と拡散: 正規化は、ノードの特徴量（この場合はアイテム埋め込み）が隣接ノードに適切に伝播・拡散されることを保証します。正規化されていない場合、高次数のノードが支配的になり、低次数のノードの情報が埋もれてしまう可能性があります。
        ### GCNの理論的根拠: LightGCNのようなGCNモデルでは、グラフ畳み込み操作がグラフ上の情報の平滑化と拡散として機能します 。正規化は、この平滑化プロセスが効果的に機能するために不可欠です。
        row_sums_graph = np.sum(user_graph_adj, axis=1, keepdims=True)
        row_sums_graph[row_sums_graph == 0] = 1 # ゼロ除算回避
        normalized_user_graph_adj = user_graph_adj / row_sums_graph
        normalized_user_graph_adj_tensor = torch.tensor(normalized_user_graph_adj, dtype=torch.float32)

        # グラフ畳み込み (R = S'' A)
        # R は (num_users, num_items, item_embedding_dim) となる
        # MatMul: (num_users, num_users) x (num_users, num_items, item_embedding_dim)
        # Einstein Summation Convention: 'ij, jkd -> ikd'
        R_tensor = torch.einsum('ij, jkd -> ikd', normalized_user_graph_adj_tensor, item_embedding_matrix_A)

        # グローバルアイテム埋め込みの更新 (θ_global = DR)
        # 論文の式(17)に相当 [cite: 113]
        # ここではDを全ユーザーの単純平均と解釈 (Rの0次元目を平均)
        new_global_item_embedding_weight = R_tensor.mean(dim=0) # (num_items, item_embedding_dim)

        # サーバーのグローバルアイテム埋め込みを直接更新
        self.global_item_embedding.weight.data.copy_(new_global_item_embedding_weight)

        return self.global_item_embedding.weight.data

# %% [markdown]
# ## 5. 学習ループの変更 (フェデレーテッド学習のシミュレーション)
# この学習ループでは、以下のステップをシミュレートします。
#
# グローバル配布: サーバーがグローバルアイテム埋め込みを各クライアントに配布します。
#
# ローカル学習: 各クライアントは自身のデータを使ってモデルを学習し、ユーザーのジョイント埋め込み層の重みと、ローカルで更新されたアイテム埋め込み（のテンソル）をサーバーにアップロードします。
#
# グラフ集約: サーバーはアップロードされたユーザー埋め込み層の重みからユーザー関係グラフを構築し、それに基づいてグローバルアイテム埋め込みを集約・更新します。

# %%
# モデルのハイパーパラメータ
item_embedding_dim = 32
joint_embedding_output_dim = 32 

# サーバーのインスタンス化
server = Server(num_users, num_items, item_embedding_dim, joint_embedding_output_dim)

# 各クライアントのモデルを辞書で保持
client_models = {}
client_optimizers = {}
for client_id in range(num_clients):
    client_models[client_id] = ClientModel(
        num_items,
        item_embedding_dim,
        plm_model,
        plm_embedding_dim,
        joint_embedding_output_dim
    )
    # NOTE:
    # クライアントごとに最適化するパラメータを設定
    # ここでは、user_joint_embedding_linear, local_item_embedding, prediction_layer が対象
    # 単純にoptim.Adam(params = client_models[client_id].parameters(), lr=0.001)とすると、
    # PLMも学習可能パラメータとなってしまうので、
    # PLMのパラメータを除外したパラメータのみを取得してから、設定する.
    trainable_params = [
        p for name, p in client_models[client_id].named_parameters()
        if not name.startswith('plm_model.')
    ]

    client_optimizers[client_id] = optim.Adam(
        params=trainable_params,
        lr=0.001
    )


# 学習ループ (フェデレーテッド学習ラウンド)
num_communication_rounds = 10
local_epochs = 1 



for round_num in range(num_communication_rounds):
    print(f"\n--- Communication Round {round_num + 1}/{num_communication_rounds} ---")

    # サーバーからグローバルアイテム埋め込みをクライアントに配布
    # 論文のステップ「Global Distribution: Updated global project embeddings are broadcast to all clients for next-round initialization.」[cite: 63]
    for client_id in range(num_clients):
        client_models[client_id].local_item_embedding.weight.data.copy_(server.global_item_embedding.weight.data)

    user_linear_weights_for_graph = {} # {user_id: user_joint_embedding_linear.weight.data (flattened)}
    user_local_item_weights_to_server = {} # {user_id: local_item_embedding.weight.data (Tensor)}

    # クライアントのローカル学習
    # 論文のステップ「Local Training」[cite: 60]
    for client_id in range(num_clients):
        model = client_models[client_id]
        optimizer = client_optimizers[client_id]
        dataloader = client_datasets[client_id]

        model.train()
        local_loss = 0

        # このクライアントが担当するユーザーID
        current_user_id = client_user_map[client_id] 

        for epoch in range(local_epochs):
            for user_ids_batch, item_ids_batch, labels_batch in dataloader: 
                current_user_texts = [user_texts[uid.item()] for uid in user_ids_batch]

                optimizer.zero_grad()

                predictions, user_joint_embedding_linear_weight, local_item_embedding_weight = model(
                    item_ids_batch, current_user_texts
                )

                # 損失計算 (L_1のみ)
                # 論文の式(10) L_1(y,y^) [cite: 91]
                loss = nn.BCELoss()(predictions.squeeze(), labels_batch)

                loss.backward()
                optimizer.step()
                local_loss += loss.item()

        # クライアントがサーバーにアップロードするパラメータを収集
        # 論文のステップ「Parameter Uploading: Clients transmit user joint embedding weights and local item embeddings to the server.」[cite: 61]
        # 各ユーザー（クライアント）は自身の user_joint_embedding_linear.weight をベクトル化してアップロード
        user_linear_weights_for_graph[current_user_id] = user_joint_embedding_linear_weight.data.clone().flatten()

        # 各ユーザー（クライアント）は自身の local_item_embedding.weight もアップロード
        user_local_item_weights_to_server[current_user_id] = local_item_embedding_weight.data.clone()

        print(f"  Client {client_id} (User {current_user_id}) local loss: {local_loss / len(dataloader):.4f}")

    # サーバーでの処理
    # 論文のステップ「Graph Aggregation: The server constructs user relation graphs from text embeddings and aggregates parameters through graph convolution.」[cite: 62]
    # ユーザー関係グラフの構築
    # 論文のステップ「Build User Relaction Graph」[cite: 102, 122]
    user_graph_adj, sorted_user_ids_for_graph = server.build_user_relationship_graph(
        user_linear_weights_for_graph
    )

    # アイテム埋め込みの集約
    # 論文のステップ「Learn user common item embeddings with Eq.(16)」[cite: 122] と
    # 「Learn globally shared item embedding θ_global with Eq.(17)」[cite: 122]
    server.aggregate_item_embeddings(
        user_local_item_weights_to_server,
        user_graph_adj,
        sorted_user_ids_for_graph
    )

    print(f"Round {round_num + 1} completed. Global item embeddings updated.")

print("Federated training completed.")
# Out:
# --- Communication Round 1/10 ---
#   Client 0 (User 0) local loss: 0.6512
#   Client 1 (User 1) local loss: 0.7042
#   Client 2 (User 2) local loss: 0.7052
#   Client 3 (User 3) local loss: 0.7133
#   Client 4 (User 4) local loss: 0.6571
#   Client 5 (User 5) local loss: 0.6896
#   Client 6 (User 6) local loss: 0.6302
#   Client 7 (User 7) local loss: 0.6649
#   Client 8 (User 8) local loss: 0.6646
#   Client 9 (User 9) local loss: 0.6635
#   Client 10 (User 10) local loss: 0.7050
#   Client 11 (User 11) local loss: 0.5996
#   Client 12 (User 12) local loss: 0.6631
#   Client 13 (User 13) local loss: 0.6504
#   Client 14 (User 14) local loss: 0.7252
#   Client 15 (User 15) local loss: 0.6619
#   Client 16 (User 16) local loss: 0.6855
#   Client 17 (User 17) local loss: 0.6503
#   Client 18 (User 18) local loss: 0.6791
#   Client 19 (User 19) local loss: 0.6758
#   Client 20 (User 20) local loss: 0.6300
#   Client 21 (User 21) local loss: 0.6566
#   Client 22 (User 22) local loss: 0.6327
#   Client 23 (User 23) local loss: 0.7275
#   Client 24 (User 24) local loss: 0.5834
#   Client 25 (User 25) local loss: 0.6581
#   Client 26 (User 26) local loss: 0.6070
#   Client 27 (User 27) local loss: 0.7122
#   Client 28 (User 28) local loss: 0.7428
#   Client 29 (User 29) local loss: 0.6550
#   Client 30 (User 30) local loss: 0.7441
#   Client 31 (User 31) local loss: 0.6296
#   Client 32 (User 32) local loss: 0.6792
#   Client 33 (User 33) local loss: 0.6292
#   Client 34 (User 34) local loss: 0.6716
#   Client 35 (User 35) local loss: 0.7510
#   Client 36 (User 36) local loss: 0.7065
#   Client 37 (User 37) local loss: 0.6943
#   Client 38 (User 38) local loss: 0.6288
#   Client 39 (User 39) local loss: 0.6378
#   Client 40 (User 40) local loss: 0.7175
#   Client 41 (User 41) local loss: 0.6540
#   Client 42 (User 42) local loss: 0.6883
#   Client 43 (User 43) local loss: 0.6965
#   Client 44 (User 44) local loss: 0.7105
#   Client 45 (User 45) local loss: 0.5900
#   Client 46 (User 46) local loss: 0.6764
#   Client 47 (User 47) local loss: 0.6497
#   Client 48 (User 48) local loss: 0.6648
#   Client 49 (User 49) local loss: 0.6652
#   Client 50 (User 50) local loss: 0.7456
#   Client 51 (User 51) local loss: 0.6644
#   Client 52 (User 52) local loss: 0.6099
#   Client 53 (User 53) local loss: 0.7337
#   Client 54 (User 54) local loss: 0.7332
#   Client 55 (User 55) local loss: 0.6825
#   Client 56 (User 56) local loss: 0.7100
#   Client 57 (User 57) local loss: 0.6951
#   Client 58 (User 58) local loss: 0.6192
#   Client 59 (User 59) local loss: 0.6556
#   Client 60 (User 60) local loss: 0.7095
#   Client 61 (User 61) local loss: 0.7184
#   Client 62 (User 62) local loss: 0.7400
#   Client 63 (User 63) local loss: 0.6749
#   Client 64 (User 64) local loss: 0.6635
#   Client 65 (User 65) local loss: 0.6304
#   Client 66 (User 66) local loss: 0.7420
#   Client 67 (User 67) local loss: 0.7604
#   Client 68 (User 68) local loss: 0.6381
#   Client 69 (User 69) local loss: 0.6921
#   Client 70 (User 70) local loss: 0.6529
#   Client 71 (User 71) local loss: 0.6908
#   Client 72 (User 72) local loss: 0.7499
#   Client 73 (User 73) local loss: 0.6479
#   Client 74 (User 74) local loss: 0.7167
#   Client 75 (User 75) local loss: 0.6861
#   Client 76 (User 76) local loss: 0.6293
#   Client 77 (User 77) local loss: 0.6811
#   Client 78 (User 78) local loss: 0.6815
#   Client 79 (User 79) local loss: 0.5920
#   Client 80 (User 80) local loss: 0.6571
#   Client 81 (User 81) local loss: 0.6838
#   Client 82 (User 82) local loss: 0.6529
#   Client 83 (User 83) local loss: 0.6432
#   Client 84 (User 84) local loss: 0.6760
#   Client 85 (User 85) local loss: 0.6308
#   Client 86 (User 86) local loss: 0.7454
#   Client 87 (User 87) local loss: 0.6747
#   Client 88 (User 88) local loss: 0.6343
#   Client 89 (User 89) local loss: 0.6873
#   Client 90 (User 90) local loss: 0.6884
#   Client 91 (User 91) local loss: 0.6442
#   Client 92 (User 92) local loss: 0.7211
#   Client 93 (User 93) local loss: 0.6179
#   Client 94 (User 94) local loss: 0.7249
#   Client 95 (User 95) local loss: 0.6452
#   Client 96 (User 96) local loss: 0.6948
#   Client 97 (User 97) local loss: 0.6242
#   Client 98 (User 98) local loss: 0.6988
#   Client 99 (User 99) local loss: 0.6598
# Round 1 completed. Global item embeddings updated.
#
# --- Communication Round 2/10 ---
#   Client 0 (User 0) local loss: 0.6074
#   Client 1 (User 1) local loss: 0.6152
#   Client 2 (User 2) local loss: 0.5662
#   Client 3 (User 3) local loss: 0.6949
#   Client 4 (User 4) local loss: 0.6377
#   Client 5 (User 5) local loss: 0.6843
#   Client 6 (User 6) local loss: 0.5207
#   Client 7 (User 7) local loss: 0.5580
#   Client 8 (User 8) local loss: 0.5567
#   Client 9 (User 9) local loss: 0.5332
#   Client 10 (User 10) local loss: 0.6355
#   Client 11 (User 11) local loss: 0.5716
#   Client 12 (User 12) local loss: 0.4997
#   Client 13 (User 13) local loss: 0.6151
#   Client 14 (User 14) local loss: 0.6913
#   Client 15 (User 15) local loss: 0.6007
#   Client 16 (User 16) local loss: 0.6614
#   Client 17 (User 17) local loss: 0.5910
#   Client 18 (User 18) local loss: 0.6327
#   Client 19 (User 19) local loss: 0.6500
#   Client 20 (User 20) local loss: 0.6314
#   Client 21 (User 21) local loss: 0.5329
#   Client 22 (User 22) local loss: 0.6341
#   Client 23 (User 23) local loss: 0.6266
#   Client 24 (User 24) local loss: 0.4681
#   Client 25 (User 25) local loss: 0.6276
#   Client 26 (User 26) local loss: 0.5221
#   Client 27 (User 27) local loss: 0.6508
#   Client 28 (User 28) local loss: 0.7229
#   Client 29 (User 29) local loss: 0.5969
#   Client 30 (User 30) local loss: 0.6971
#   Client 31 (User 31) local loss: 0.5688
#   Client 32 (User 32) local loss: 0.6552
#   Client 33 (User 33) local loss: 0.5789
#   Client 34 (User 34) local loss: 0.6275
#   Client 35 (User 35) local loss: 0.6981
#   Client 36 (User 36) local loss: 0.5517
#   Client 37 (User 37) local loss: 0.6855
#   Client 38 (User 38) local loss: 0.5688
#   Client 39 (User 39) local loss: 0.6323
#   Client 40 (User 40) local loss: 0.6929
#   Client 41 (User 41) local loss: 0.6128
#   Client 42 (User 42) local loss: 0.5556
#   Client 43 (User 43) local loss: 0.6787
#   Client 44 (User 44) local loss: 0.5982
#   Client 45 (User 45) local loss: 0.5154
#   Client 46 (User 46) local loss: 0.6103
#   Client 47 (User 47) local loss: 0.6288
#   Client 48 (User 48) local loss: 0.6507
#   Client 49 (User 49) local loss: 0.6602
#   Client 50 (User 50) local loss: 0.6519
#   Client 51 (User 51) local loss: 0.6424
#   Client 52 (User 52) local loss: 0.5539
#   Client 53 (User 53) local loss: 0.7320
#   Client 54 (User 54) local loss: 0.6709
#   Client 55 (User 55) local loss: 0.5889
#   Client 56 (User 56) local loss: 0.5656
#   Client 57 (User 57) local loss: 0.6832
#   Client 58 (User 58) local loss: 0.5743
#   Client 59 (User 59) local loss: 0.6232
#   Client 60 (User 60) local loss: 0.7124
#   Client 61 (User 61) local loss: 0.6781
#   Client 62 (User 62) local loss: 0.6982
#   Client 63 (User 63) local loss: 0.5886
#   Client 64 (User 64) local loss: 0.5358
#   Client 65 (User 65) local loss: 0.5901
#   Client 66 (User 66) local loss: 0.7172
#   Client 67 (User 67) local loss: 0.6459
#   Client 68 (User 68) local loss: 0.5366
#   Client 69 (User 69) local loss: 0.6761
#   Client 70 (User 70) local loss: 0.6031
#   Client 71 (User 71) local loss: 0.6428
#   Client 72 (User 72) local loss: 0.7349
#   Client 73 (User 73) local loss: 0.5953
#   Client 74 (User 74) local loss: 0.6652
#   Client 75 (User 75) local loss: 0.6249
#   Client 76 (User 76) local loss: 0.5902
#   Client 77 (User 77) local loss: 0.5882
#   Client 78 (User 78) local loss: 0.6551
#   Client 79 (User 79) local loss: 0.5679
#   Client 80 (User 80) local loss: 0.6219
#   Client 81 (User 81) local loss: 0.5015
#   Client 82 (User 82) local loss: 0.6089
#   Client 83 (User 83) local loss: 0.5756
#   Client 84 (User 84) local loss: 0.6148
#   Client 85 (User 85) local loss: 0.5568
#   Client 86 (User 86) local loss: 0.7300
#   Client 87 (User 87) local loss: 0.6722
#   Client 88 (User 88) local loss: 0.6086
#   Client 89 (User 89) local loss: 0.6189
#   Client 90 (User 90) local loss: 0.6640
#   Client 91 (User 91) local loss: 0.5676
#   Client 92 (User 92) local loss: 0.5295
#   Client 93 (User 93) local loss: 0.6105
#   Client 94 (User 94) local loss: 0.6347
#   Client 95 (User 95) local loss: 0.6205
#   Client 96 (User 96) local loss: 0.6252
#   Client 97 (User 97) local loss: 0.5931
#   Client 98 (User 98) local loss: 0.6268
#   Client 99 (User 99) local loss: 0.6056
# Round 2 completed. Global item embeddings updated.
#
# --- Communication Round 3/10 ---
#   Client 0 (User 0) local loss: 0.6106
#   Client 1 (User 1) local loss: 0.6180
#   Client 2 (User 2) local loss: 0.5523
#   Client 3 (User 3) local loss: 0.6883
#   Client 4 (User 4) local loss: 0.6356
#   Client 5 (User 5) local loss: 0.6728
#   Client 6 (User 6) local loss: 0.5133
#   Client 7 (User 7) local loss: 0.5296
#   Client 8 (User 8) local loss: 0.5271
#   Client 9 (User 9) local loss: 0.5459
#   Client 10 (User 10) local loss: 0.6394
#   Client 11 (User 11) local loss: 0.5841
#   Client 12 (User 12) local loss: 0.4591
#   Client 13 (User 13) local loss: 0.6211
#   Client 14 (User 14) local loss: 0.6610
#   Client 15 (User 15) local loss: 0.6034
#   Client 16 (User 16) local loss: 0.6600
#   Client 17 (User 17) local loss: 0.6131
#   Client 18 (User 18) local loss: 0.6411
#   Client 19 (User 19) local loss: 0.6567
#   Client 20 (User 20) local loss: 0.6275
#   Client 21 (User 21) local loss: 0.5273
#   Client 22 (User 22) local loss: 0.6231
#   Client 23 (User 23) local loss: 0.5841
#   Client 24 (User 24) local loss: 0.4582
#   Client 25 (User 25) local loss: 0.6132
#   Client 26 (User 26) local loss: 0.5186
#   Client 27 (User 27) local loss: 0.6584
#   Client 28 (User 28) local loss: 0.7172
#   Client 29 (User 29) local loss: 0.5959
#   Client 30 (User 30) local loss: 0.6752
#   Client 31 (User 31) local loss: 0.5490
#   Client 32 (User 32) local loss: 0.6468
#   Client 33 (User 33) local loss: 0.5899
#   Client 34 (User 34) local loss: 0.6259
#   Client 35 (User 35) local loss: 0.7098
#   Client 36 (User 36) local loss: 0.5387
#   Client 37 (User 37) local loss: 0.6817
#   Client 38 (User 38) local loss: 0.5806
#   Client 39 (User 39) local loss: 0.6108
#   Client 40 (User 40) local loss: 0.6860
#   Client 41 (User 41) local loss: 0.6020
#   Client 42 (User 42) local loss: 0.5062
#   Client 43 (User 43) local loss: 0.6767
#   Client 44 (User 44) local loss: 0.6051
#   Client 45 (User 45) local loss: 0.5070
#   Client 46 (User 46) local loss: 0.6284
#   Client 47 (User 47) local loss: 0.6177
#   Client 48 (User 48) local loss: 0.6297
#   Client 49 (User 49) local loss: 0.6553
#   Client 50 (User 50) local loss: 0.6497
#   Client 51 (User 51) local loss: 0.6413
#   Client 52 (User 52) local loss: 0.5050
#   Client 53 (User 53) local loss: 0.7291
#   Client 54 (User 54) local loss: 0.6470
#   Client 55 (User 55) local loss: 0.5765
#   Client 56 (User 56) local loss: 0.5297
#   Client 57 (User 57) local loss: 0.6675
#   Client 58 (User 58) local loss: 0.5668
#   Client 59 (User 59) local loss: 0.6272
#   Client 60 (User 60) local loss: 0.7011
#   Client 61 (User 61) local loss: 0.6831
#   Client 62 (User 62) local loss: 0.6851
#   Client 63 (User 63) local loss: 0.5696
#   Client 64 (User 64) local loss: 0.5323
#   Client 65 (User 65) local loss: 0.6004
#   Client 66 (User 66) local loss: 0.7085
#   Client 67 (User 67) local loss: 0.5996
#   Client 68 (User 68) local loss: 0.5389
#   Client 69 (User 69) local loss: 0.6615
#   Client 70 (User 70) local loss: 0.6039
#   Client 71 (User 71) local loss: 0.6319
#   Client 72 (User 72) local loss: 0.7130
#   Client 73 (User 73) local loss: 0.5954
#   Client 74 (User 74) local loss: 0.6763
#   Client 75 (User 75) local loss: 0.6261
#   Client 76 (User 76) local loss: 0.5757
#   Client 77 (User 77) local loss: 0.5906
#   Client 78 (User 78) local loss: 0.6558
#   Client 79 (User 79) local loss: 0.5697
#   Client 80 (User 80) local loss: 0.5822
#   Client 81 (User 81) local loss: 0.4381
#   Client 82 (User 82) local loss: 0.6257
#   Client 83 (User 83) local loss: 0.5535
#   Client 84 (User 84) local loss: 0.6125
#   Client 85 (User 85) local loss: 0.5616
#   Client 86 (User 86) local loss: 0.7196
#   Client 87 (User 87) local loss: 0.6650
#   Client 88 (User 88) local loss: 0.5975
#   Client 89 (User 89) local loss: 0.6200
#   Client 90 (User 90) local loss: 0.6716
#   Client 91 (User 91) local loss: 0.5695
#   Client 92 (User 92) local loss: 0.4926
#   Client 93 (User 93) local loss: 0.5928
#   Client 94 (User 94) local loss: 0.6603
#   Client 95 (User 95) local loss: 0.6319
#   Client 96 (User 96) local loss: 0.6366
#   Client 97 (User 97) local loss: 0.5987
#   Client 98 (User 98) local loss: 0.6079
#   Client 99 (User 99) local loss: 0.5844
# Round 3 completed. Global item embeddings updated.
#
# --- Communication Round 4/10 ---
#   Client 0 (User 0) local loss: 0.6059
#   Client 1 (User 1) local loss: 0.6148
#   Client 2 (User 2) local loss: 0.5272
#   Client 3 (User 3) local loss: 0.6893
#   Client 4 (User 4) local loss: 0.6325
#   Client 5 (User 5) local loss: 0.6648
#   Client 6 (User 6) local loss: 0.4792
#   Client 7 (User 7) local loss: 0.5212
#   Client 8 (User 8) local loss: 0.5389
#   Client 9 (User 9) local loss: 0.5191
#   Client 10 (User 10) local loss: 0.6247
#   Client 11 (User 11) local loss: 0.5581
#   Client 12 (User 12) local loss: 0.4646
#   Client 13 (User 13) local loss: 0.6140
#   Client 14 (User 14) local loss: 0.6640
#   Client 15 (User 15) local loss: 0.5956
#   Client 16 (User 16) local loss: 0.6569
#   Client 17 (User 17) local loss: 0.5962
#   Client 18 (User 18) local loss: 0.6282
#   Client 19 (User 19) local loss: 0.6505
#   Client 20 (User 20) local loss: 0.6066
#   Client 21 (User 21) local loss: 0.5384
#   Client 22 (User 22) local loss: 0.6260
#   Client 23 (User 23) local loss: 0.5907
#   Client 24 (User 24) local loss: 0.4551
#   Client 25 (User 25) local loss: 0.6289
#   Client 26 (User 26) local loss: 0.5271
#   Client 27 (User 27) local loss: 0.6573
#   Client 28 (User 28) local loss: 0.7190
#   Client 29 (User 29) local loss: 0.5851
#   Client 30 (User 30) local loss: 0.6751
#   Client 31 (User 31) local loss: 0.5674
#   Client 32 (User 32) local loss: 0.6250
#   Client 33 (User 33) local loss: 0.5912
#   Client 34 (User 34) local loss: 0.6083
#   Client 35 (User 35) local loss: 0.6905
#   Client 36 (User 36) local loss: 0.5439
#   Client 37 (User 37) local loss: 0.6735
#   Client 38 (User 38) local loss: 0.5722
#   Client 39 (User 39) local loss: 0.5969
#   Client 40 (User 40) local loss: 0.6757
#   Client 41 (User 41) local loss: 0.5931
#   Client 42 (User 42) local loss: 0.4990
#   Client 43 (User 43) local loss: 0.6707
#   Client 44 (User 44) local loss: 0.6075
#   Client 45 (User 45) local loss: 0.5155
#   Client 46 (User 46) local loss: 0.6103
#   Client 47 (User 47) local loss: 0.6130
#   Client 48 (User 48) local loss: 0.6229
#   Client 49 (User 49) local loss: 0.6319
#   Client 50 (User 50) local loss: 0.6508
#   Client 51 (User 51) local loss: 0.6369
#   Client 52 (User 52) local loss: 0.5165
#   Client 53 (User 53) local loss: 0.7237
#   Client 54 (User 54) local loss: 0.6402
#   Client 55 (User 55) local loss: 0.5910
#   Client 56 (User 56) local loss: 0.5127
#   Client 57 (User 57) local loss: 0.6757
#   Client 58 (User 58) local loss: 0.5728
#   Client 59 (User 59) local loss: 0.6184
#   Client 60 (User 60) local loss: 0.6934
#   Client 61 (User 61) local loss: 0.6784
#   Client 62 (User 62) local loss: 0.7027
#   Client 63 (User 63) local loss: 0.5774
#   Client 64 (User 64) local loss: 0.5337
#   Client 65 (User 65) local loss: 0.5931
#   Client 66 (User 66) local loss: 0.7094
#   Client 67 (User 67) local loss: 0.6159
#   Client 68 (User 68) local loss: 0.5405
#   Client 69 (User 69) local loss: 0.6556
#   Client 70 (User 70) local loss: 0.6038
#   Client 71 (User 71) local loss: 0.6258
#   Client 72 (User 72) local loss: 0.7205
#   Client 73 (User 73) local loss: 0.5861
#   Client 74 (User 74) local loss: 0.6737
#   Client 75 (User 75) local loss: 0.6125
#   Client 76 (User 76) local loss: 0.5714
#   Client 77 (User 77) local loss: 0.5845
#   Client 78 (User 78) local loss: 0.6426
#   Client 79 (User 79) local loss: 0.5683
#   Client 80 (User 80) local loss: 0.5623
#   Client 81 (User 81) local loss: 0.4398
#   Client 82 (User 82) local loss: 0.6117
#   Client 83 (User 83) local loss: 0.5888
#   Client 84 (User 84) local loss: 0.6154
#   Client 85 (User 85) local loss: 0.5596
#   Client 86 (User 86) local loss: 0.7118
#   Client 87 (User 87) local loss: 0.6515
#   Client 88 (User 88) local loss: 0.5995
#   Client 89 (User 89) local loss: 0.6296
#   Client 90 (User 90) local loss: 0.6624
#   Client 91 (User 91) local loss: 0.5690
#   Client 92 (User 92) local loss: 0.4990
#   Client 93 (User 93) local loss: 0.6105
#   Client 94 (User 94) local loss: 0.6382
#   Client 95 (User 95) local loss: 0.6236
#   Client 96 (User 96) local loss: 0.6362
#   Client 97 (User 97) local loss: 0.5831
#   Client 98 (User 98) local loss: 0.6040
#   Client 99 (User 99) local loss: 0.5871
# Round 4 completed. Global item embeddings updated.
#
# --- Communication Round 5/10 ---
#   Client 0 (User 0) local loss: 0.5962
#   Client 1 (User 1) local loss: 0.6108
#   Client 2 (User 2) local loss: 0.5190
#   Client 3 (User 3) local loss: 0.6766
#   Client 4 (User 4) local loss: 0.6320
#   Client 5 (User 5) local loss: 0.6739
#   Client 6 (User 6) local loss: 0.4846
#   Client 7 (User 7) local loss: 0.5282
#   Client 8 (User 8) local loss: 0.5362
#   Client 9 (User 9) local loss: 0.5354
#   Client 10 (User 10) local loss: 0.6231
#   Client 11 (User 11) local loss: 0.5428
#   Client 12 (User 12) local loss: 0.4839
#   Client 13 (User 13) local loss: 0.6151
#   Client 14 (User 14) local loss: 0.6559
#   Client 15 (User 15) local loss: 0.5898
#   Client 16 (User 16) local loss: 0.6478
#   Client 17 (User 17) local loss: 0.5876
#   Client 18 (User 18) local loss: 0.6099
#   Client 19 (User 19) local loss: 0.6321
#   Client 20 (User 20) local loss: 0.6084
#   Client 21 (User 21) local loss: 0.5232
#   Client 22 (User 22) local loss: 0.6107
#   Client 23 (User 23) local loss: 0.5833
#   Client 24 (User 24) local loss: 0.4416
#   Client 25 (User 25) local loss: 0.6146
#   Client 26 (User 26) local loss: 0.5172
#   Client 27 (User 27) local loss: 0.6266
#   Client 28 (User 28) local loss: 0.7104
#   Client 29 (User 29) local loss: 0.5946
#   Client 30 (User 30) local loss: 0.6705
#   Client 31 (User 31) local loss: 0.5670
#   Client 32 (User 32) local loss: 0.6170
#   Client 33 (User 33) local loss: 0.5918
#   Client 34 (User 34) local loss: 0.6061
#   Client 35 (User 35) local loss: 0.6789
#   Client 36 (User 36) local loss: 0.5540
#   Client 37 (User 37) local loss: 0.6619
#   Client 38 (User 38) local loss: 0.5564
#   Client 39 (User 39) local loss: 0.5947
#   Client 40 (User 40) local loss: 0.6725
#   Client 41 (User 41) local loss: 0.5798
#   Client 42 (User 42) local loss: 0.4954
#   Client 43 (User 43) local loss: 0.6592
#   Client 44 (User 44) local loss: 0.5950
#   Client 45 (User 45) local loss: 0.5064
#   Client 46 (User 46) local loss: 0.6139
#   Client 47 (User 47) local loss: 0.6042
#   Client 48 (User 48) local loss: 0.6255
#   Client 49 (User 49) local loss: 0.6393
#   Client 50 (User 50) local loss: 0.6372
#   Client 51 (User 51) local loss: 0.6263
#   Client 52 (User 52) local loss: 0.5285
#   Client 53 (User 53) local loss: 0.7193
#   Client 54 (User 54) local loss: 0.6574
#   Client 55 (User 55) local loss: 0.5939
#   Client 56 (User 56) local loss: 0.5166
#   Client 57 (User 57) local loss: 0.6634
#   Client 58 (User 58) local loss: 0.5773
#   Client 59 (User 59) local loss: 0.6083
#   Client 60 (User 60) local loss: 0.6890
#   Client 61 (User 61) local loss: 0.6485
#   Client 62 (User 62) local loss: 0.6927
#   Client 63 (User 63) local loss: 0.5881
#   Client 64 (User 64) local loss: 0.5194
#   Client 65 (User 65) local loss: 0.5875
#   Client 66 (User 66) local loss: 0.6954
#   Client 67 (User 67) local loss: 0.5993
#   Client 68 (User 68) local loss: 0.5378
#   Client 69 (User 69) local loss: 0.6546
#   Client 70 (User 70) local loss: 0.5857
#   Client 71 (User 71) local loss: 0.5972
#   Client 72 (User 72) local loss: 0.7008
#   Client 73 (User 73) local loss: 0.5965
#   Client 74 (User 74) local loss: 0.6536
#   Client 75 (User 75) local loss: 0.6111
#   Client 76 (User 76) local loss: 0.5660
#   Client 77 (User 77) local loss: 0.5839
#   Client 78 (User 78) local loss: 0.6366
#   Client 79 (User 79) local loss: 0.5564
#   Client 80 (User 80) local loss: 0.5665
#   Client 81 (User 81) local loss: 0.4668
#   Client 82 (User 82) local loss: 0.6033
#   Client 83 (User 83) local loss: 0.5547
#   Client 84 (User 84) local loss: 0.5925
#   Client 85 (User 85) local loss: 0.5575
#   Client 86 (User 86) local loss: 0.7129
#   Client 87 (User 87) local loss: 0.6497
#   Client 88 (User 88) local loss: 0.5879
#   Client 89 (User 89) local loss: 0.6087
#   Client 90 (User 90) local loss: 0.6465
#   Client 91 (User 91) local loss: 0.5643
#   Client 92 (User 92) local loss: 0.5027
#   Client 93 (User 93) local loss: 0.5952
#   Client 94 (User 94) local loss: 0.6364
#   Client 95 (User 95) local loss: 0.6154
#   Client 96 (User 96) local loss: 0.6332
#   Client 97 (User 97) local loss: 0.5755
#   Client 98 (User 98) local loss: 0.6018
#   Client 99 (User 99) local loss: 0.6147
# Round 5 completed. Global item embeddings updated.
#
# --- Communication Round 6/10 ---
#   Client 0 (User 0) local loss: 0.6040
#   Client 1 (User 1) local loss: 0.5917
#   Client 2 (User 2) local loss: 0.5456
#   Client 3 (User 3) local loss: 0.6797
#   Client 4 (User 4) local loss: 0.6211
#   Client 5 (User 5) local loss: 0.6623
#   Client 6 (User 6) local loss: 0.4898
#   Client 7 (User 7) local loss: 0.5147
#   Client 8 (User 8) local loss: 0.5410
#   Client 9 (User 9) local loss: 0.5250
#   Client 10 (User 10) local loss: 0.6128
#   Client 11 (User 11) local loss: 0.5549
#   Client 12 (User 12) local loss: 0.4640
#   Client 13 (User 13) local loss: 0.6046
#   Client 14 (User 14) local loss: 0.6495
#   Client 15 (User 15) local loss: 0.5943
#   Client 16 (User 16) local loss: 0.6394
#   Client 17 (User 17) local loss: 0.5770
#   Client 18 (User 18) local loss: 0.6260
#   Client 19 (User 19) local loss: 0.6183
#   Client 20 (User 20) local loss: 0.5922
#   Client 21 (User 21) local loss: 0.5181
#   Client 22 (User 22) local loss: 0.6126
#   Client 23 (User 23) local loss: 0.6029
#   Client 24 (User 24) local loss: 0.4317
#   Client 25 (User 25) local loss: 0.6109
#   Client 26 (User 26) local loss: 0.5040
#   Client 27 (User 27) local loss: 0.6240
#   Client 28 (User 28) local loss: 0.7003
#   Client 29 (User 29) local loss: 0.5913
#   Client 30 (User 30) local loss: 0.6491
#   Client 31 (User 31) local loss: 0.5446
#   Client 32 (User 32) local loss: 0.6123
#   Client 33 (User 33) local loss: 0.5855
#   Client 34 (User 34) local loss: 0.5994
#   Client 35 (User 35) local loss: 0.6820
#   Client 36 (User 36) local loss: 0.5297
#   Client 37 (User 37) local loss: 0.6641
#   Client 38 (User 38) local loss: 0.5584
#   Client 39 (User 39) local loss: 0.5940
#   Client 40 (User 40) local loss: 0.6658
#   Client 41 (User 41) local loss: 0.5733
#   Client 42 (User 42) local loss: 0.4846
#   Client 43 (User 43) local loss: 0.6569
#   Client 44 (User 44) local loss: 0.5987
#   Client 45 (User 45) local loss: 0.4791
#   Client 46 (User 46) local loss: 0.6030
#   Client 47 (User 47) local loss: 0.6041
#   Client 48 (User 48) local loss: 0.6151
#   Client 49 (User 49) local loss: 0.6161
#   Client 50 (User 50) local loss: 0.6183
#   Client 51 (User 51) local loss: 0.6222
#   Client 52 (User 52) local loss: 0.5175
#   Client 53 (User 53) local loss: 0.7123
#   Client 54 (User 54) local loss: 0.6338
#   Client 55 (User 55) local loss: 0.5686
#   Client 56 (User 56) local loss: 0.5064
#   Client 57 (User 57) local loss: 0.6548
#   Client 58 (User 58) local loss: 0.5608
#   Client 59 (User 59) local loss: 0.6030
#   Client 60 (User 60) local loss: 0.6819
#   Client 61 (User 61) local loss: 0.6674
#   Client 62 (User 62) local loss: 0.6784
#   Client 63 (User 63) local loss: 0.5584
#   Client 64 (User 64) local loss: 0.4970
#   Client 65 (User 65) local loss: 0.5726
#   Client 66 (User 66) local loss: 0.6910
#   Client 67 (User 67) local loss: 0.5874
#   Client 68 (User 68) local loss: 0.5278
#   Client 69 (User 69) local loss: 0.6632
#   Client 70 (User 70) local loss: 0.5856
#   Client 71 (User 71) local loss: 0.6224
#   Client 72 (User 72) local loss: 0.7002
#   Client 73 (User 73) local loss: 0.5756
#   Client 74 (User 74) local loss: 0.6489
#   Client 75 (User 75) local loss: 0.6078
#   Client 76 (User 76) local loss: 0.5607
#   Client 77 (User 77) local loss: 0.5813
#   Client 78 (User 78) local loss: 0.6334
#   Client 79 (User 79) local loss: 0.5543
#   Client 80 (User 80) local loss: 0.5662
#   Client 81 (User 81) local loss: 0.4495
#   Client 82 (User 82) local loss: 0.6028
#   Client 83 (User 83) local loss: 0.5602
#   Client 84 (User 84) local loss: 0.5862
#   Client 85 (User 85) local loss: 0.5381
#   Client 86 (User 86) local loss: 0.7019
#   Client 87 (User 87) local loss: 0.6396
#   Client 88 (User 88) local loss: 0.5875
#   Client 89 (User 89) local loss: 0.5996
#   Client 90 (User 90) local loss: 0.6397
#   Client 91 (User 91) local loss: 0.5655
#   Client 92 (User 92) local loss: 0.4903
#   Client 93 (User 93) local loss: 0.5929
#   Client 94 (User 94) local loss: 0.6363
#   Client 95 (User 95) local loss: 0.6112
#   Client 96 (User 96) local loss: 0.6303
#   Client 97 (User 97) local loss: 0.5725
#   Client 98 (User 98) local loss: 0.5945
#   Client 99 (User 99) local loss: 0.5917
# Round 6 completed. Global item embeddings updated.
#
# --- Communication Round 7/10 ---
#   Client 0 (User 0) local loss: 0.5849
#   Client 1 (User 1) local loss: 0.6033
#   Client 2 (User 2) local loss: 0.5157
#   Client 3 (User 3) local loss: 0.6802
#   Client 4 (User 4) local loss: 0.6049
#   Client 5 (User 5) local loss: 0.6532
#   Client 6 (User 6) local loss: 0.4881
#   Client 7 (User 7) local loss: 0.5247
#   Client 8 (User 8) local loss: 0.5234
#   Client 9 (User 9) local loss: 0.5177
#   Client 10 (User 10) local loss: 0.6040
#   Client 11 (User 11) local loss: 0.5307
#   Client 12 (User 12) local loss: 0.4773
#   Client 13 (User 13) local loss: 0.6041
#   Client 14 (User 14) local loss: 0.6471
#   Client 15 (User 15) local loss: 0.5927
#   Client 16 (User 16) local loss: 0.6564
#   Client 17 (User 17) local loss: 0.5787
#   Client 18 (User 18) local loss: 0.6125
#   Client 19 (User 19) local loss: 0.6201
#   Client 20 (User 20) local loss: 0.6031
#   Client 21 (User 21) local loss: 0.5232
#   Client 22 (User 22) local loss: 0.6023
#   Client 23 (User 23) local loss: 0.5816
#   Client 24 (User 24) local loss: 0.4523
#   Client 25 (User 25) local loss: 0.6156
#   Client 26 (User 26) local loss: 0.5046
#   Client 27 (User 27) local loss: 0.6168
#   Client 28 (User 28) local loss: 0.7067
#   Client 29 (User 29) local loss: 0.5795
#   Client 30 (User 30) local loss: 0.6511
#   Client 31 (User 31) local loss: 0.5414
#   Client 32 (User 32) local loss: 0.6162
#   Client 33 (User 33) local loss: 0.5810
#   Client 34 (User 34) local loss: 0.6033
#   Client 35 (User 35) local loss: 0.6697
#   Client 36 (User 36) local loss: 0.5495
#   Client 37 (User 37) local loss: 0.6611
#   Client 38 (User 38) local loss: 0.5587
#   Client 39 (User 39) local loss: 0.5910
#   Client 40 (User 40) local loss: 0.6690
#   Client 41 (User 41) local loss: 0.5660
#   Client 42 (User 42) local loss: 0.4737
#   Client 43 (User 43) local loss: 0.6544
#   Client 44 (User 44) local loss: 0.5986
#   Client 45 (User 45) local loss: 0.4943
#   Client 46 (User 46) local loss: 0.5876
#   Client 47 (User 47) local loss: 0.5927
#   Client 48 (User 48) local loss: 0.6100
#   Client 49 (User 49) local loss: 0.6134
#   Client 50 (User 50) local loss: 0.6230
#   Client 51 (User 51) local loss: 0.6196
#   Client 52 (User 52) local loss: 0.5088
#   Client 53 (User 53) local loss: 0.7149
#   Client 54 (User 54) local loss: 0.6221
#   Client 55 (User 55) local loss: 0.5869
#   Client 56 (User 56) local loss: 0.4709
#   Client 57 (User 57) local loss: 0.6510
#   Client 58 (User 58) local loss: 0.5439
#   Client 59 (User 59) local loss: 0.5858
#   Client 60 (User 60) local loss: 0.6767
#   Client 61 (User 61) local loss: 0.6487
#   Client 62 (User 62) local loss: 0.6780
#   Client 63 (User 63) local loss: 0.5512
#   Client 64 (User 64) local loss: 0.4961
#   Client 65 (User 65) local loss: 0.5754
#   Client 66 (User 66) local loss: 0.6908
#   Client 67 (User 67) local loss: 0.5818
#   Client 68 (User 68) local loss: 0.5118
#   Client 69 (User 69) local loss: 0.6491
#   Client 70 (User 70) local loss: 0.5802
#   Client 71 (User 71) local loss: 0.6164
#   Client 72 (User 72) local loss: 0.7001
#   Client 73 (User 73) local loss: 0.5814
#   Client 74 (User 74) local loss: 0.6477
#   Client 75 (User 75) local loss: 0.6075
#   Client 76 (User 76) local loss: 0.5500
#   Client 77 (User 77) local loss: 0.5745
#   Client 78 (User 78) local loss: 0.6313
#   Client 79 (User 79) local loss: 0.5443
#   Client 80 (User 80) local loss: 0.5693
#   Client 81 (User 81) local loss: 0.4167
#   Client 82 (User 82) local loss: 0.6094
#   Client 83 (User 83) local loss: 0.5514
#   Client 84 (User 84) local loss: 0.5965
#   Client 85 (User 85) local loss: 0.5603
#   Client 86 (User 86) local loss: 0.6939
#   Client 87 (User 87) local loss: 0.6401
#   Client 88 (User 88) local loss: 0.5816
#   Client 89 (User 89) local loss: 0.6011
#   Client 90 (User 90) local loss: 0.6348
#   Client 91 (User 91) local loss: 0.5519
#   Client 92 (User 92) local loss: 0.4737
#   Client 93 (User 93) local loss: 0.5788
#   Client 94 (User 94) local loss: 0.6351
#   Client 95 (User 95) local loss: 0.6105
#   Client 96 (User 96) local loss: 0.6177
#   Client 97 (User 97) local loss: 0.5609
#   Client 98 (User 98) local loss: 0.5799
#   Client 99 (User 99) local loss: 0.5843
# Round 7 completed. Global item embeddings updated.
#
# --- Communication Round 8/10 ---
#   Client 0 (User 0) local loss: 0.5785
#   Client 1 (User 1) local loss: 0.5981
#   Client 2 (User 2) local loss: 0.5198
#   Client 3 (User 3) local loss: 0.6691
#   Client 4 (User 4) local loss: 0.6125
#   Client 5 (User 5) local loss: 0.6555
#   Client 6 (User 6) local loss: 0.4872
#   Client 7 (User 7) local loss: 0.5351
#   Client 8 (User 8) local loss: 0.5170
#   Client 9 (User 9) local loss: 0.5163
#   Client 10 (User 10) local loss: 0.5952
#   Client 11 (User 11) local loss: 0.5349
#   Client 12 (User 12) local loss: 0.4549
#   Client 13 (User 13) local loss: 0.6001
#   Client 14 (User 14) local loss: 0.6381
#   Client 15 (User 15) local loss: 0.5877
#   Client 16 (User 16) local loss: 0.6339
#   Client 17 (User 17) local loss: 0.5835
#   Client 18 (User 18) local loss: 0.6032
#   Client 19 (User 19) local loss: 0.6308
#   Client 20 (User 20) local loss: 0.6084
#   Client 21 (User 21) local loss: 0.5089
#   Client 22 (User 22) local loss: 0.5998
#   Client 23 (User 23) local loss: 0.5712
#   Client 24 (User 24) local loss: 0.4397
#   Client 25 (User 25) local loss: 0.5998
#   Client 26 (User 26) local loss: 0.4951
#   Client 27 (User 27) local loss: 0.6172
#   Client 28 (User 28) local loss: 0.7028
#   Client 29 (User 29) local loss: 0.5621
#   Client 30 (User 30) local loss: 0.6492
#   Client 31 (User 31) local loss: 0.5473
#   Client 32 (User 32) local loss: 0.6104
#   Client 33 (User 33) local loss: 0.5725
#   Client 34 (User 34) local loss: 0.5970
#   Client 35 (User 35) local loss: 0.6646
#   Client 36 (User 36) local loss: 0.5308
#   Client 37 (User 37) local loss: 0.6654
#   Client 38 (User 38) local loss: 0.5429
#   Client 39 (User 39) local loss: 0.5928
#   Client 40 (User 40) local loss: 0.6662
#   Client 41 (User 41) local loss: 0.5720
#   Client 42 (User 42) local loss: 0.4827
#   Client 43 (User 43) local loss: 0.6444
#   Client 44 (User 44) local loss: 0.5761
#   Client 45 (User 45) local loss: 0.4862
#   Client 46 (User 46) local loss: 0.5875
#   Client 47 (User 47) local loss: 0.5976
#   Client 48 (User 48) local loss: 0.6184
#   Client 49 (User 49) local loss: 0.6120
#   Client 50 (User 50) local loss: 0.6161
#   Client 51 (User 51) local loss: 0.6157
#   Client 52 (User 52) local loss: 0.5069
#   Client 53 (User 53) local loss: 0.7185
#   Client 54 (User 54) local loss: 0.6223
#   Client 55 (User 55) local loss: 0.5743
#   Client 56 (User 56) local loss: 0.4953
#   Client 57 (User 57) local loss: 0.6536
#   Client 58 (User 58) local loss: 0.5633
#   Client 59 (User 59) local loss: 0.5968
#   Client 60 (User 60) local loss: 0.6710
#   Client 61 (User 61) local loss: 0.6410
#   Client 62 (User 62) local loss: 0.6774
#   Client 63 (User 63) local loss: 0.5408
#   Client 64 (User 64) local loss: 0.4970
#   Client 65 (User 65) local loss: 0.5808
#   Client 66 (User 66) local loss: 0.6833
#   Client 67 (User 67) local loss: 0.5873
#   Client 68 (User 68) local loss: 0.5131
#   Client 69 (User 69) local loss: 0.6495
#   Client 70 (User 70) local loss: 0.5706
#   Client 71 (User 71) local loss: 0.6086
#   Client 72 (User 72) local loss: 0.6841
#   Client 73 (User 73) local loss: 0.5729
#   Client 74 (User 74) local loss: 0.6430
#   Client 75 (User 75) local loss: 0.5918
#   Client 76 (User 76) local loss: 0.5527
#   Client 77 (User 77) local loss: 0.5517
#   Client 78 (User 78) local loss: 0.6262
#   Client 79 (User 79) local loss: 0.5480
#   Client 80 (User 80) local loss: 0.5661
#   Client 81 (User 81) local loss: 0.4326
#   Client 82 (User 82) local loss: 0.6073
#   Client 83 (User 83) local loss: 0.5477
#   Client 84 (User 84) local loss: 0.5811
#   Client 85 (User 85) local loss: 0.5469
#   Client 86 (User 86) local loss: 0.6923
#   Client 87 (User 87) local loss: 0.6489
#   Client 88 (User 88) local loss: 0.5775
#   Client 89 (User 89) local loss: 0.5849
#   Client 90 (User 90) local loss: 0.6329
#   Client 91 (User 91) local loss: 0.5552
#   Client 92 (User 92) local loss: 0.4578
#   Client 93 (User 93) local loss: 0.5778
#   Client 94 (User 94) local loss: 0.6221
#   Client 95 (User 95) local loss: 0.6070
#   Client 96 (User 96) local loss: 0.6123
#   Client 97 (User 97) local loss: 0.5607
#   Client 98 (User 98) local loss: 0.5871
#   Client 99 (User 99) local loss: 0.5849
# Round 8 completed. Global item embeddings updated.
#
# --- Communication Round 9/10 ---
#   Client 0 (User 0) local loss: 0.5840
#   Client 1 (User 1) local loss: 0.5852
#   Client 2 (User 2) local loss: 0.5152
#   Client 3 (User 3) local loss: 0.6610
#   Client 4 (User 4) local loss: 0.6003
#   Client 5 (User 5) local loss: 0.6516
#   Client 6 (User 6) local loss: 0.4661
#   Client 7 (User 7) local loss: 0.5240
#   Client 8 (User 8) local loss: 0.5183
#   Client 9 (User 9) local loss: 0.5089
#   Client 10 (User 10) local loss: 0.6046
#   Client 11 (User 11) local loss: 0.5374
#   Client 12 (User 12) local loss: 0.4571
#   Client 13 (User 13) local loss: 0.5952
#   Client 14 (User 14) local loss: 0.6349
#   Client 15 (User 15) local loss: 0.5852
#   Client 16 (User 16) local loss: 0.6193
#   Client 17 (User 17) local loss: 0.5763
#   Client 18 (User 18) local loss: 0.5958
#   Client 19 (User 19) local loss: 0.6272
#   Client 20 (User 20) local loss: 0.5880
#   Client 21 (User 21) local loss: 0.5164
#   Client 22 (User 22) local loss: 0.5979
#   Client 23 (User 23) local loss: 0.5762
#   Client 24 (User 24) local loss: 0.4264
#   Client 25 (User 25) local loss: 0.6007
#   Client 26 (User 26) local loss: 0.4917
#   Client 27 (User 27) local loss: 0.6100
#   Client 28 (User 28) local loss: 0.6933
#   Client 29 (User 29) local loss: 0.5660
#   Client 30 (User 30) local loss: 0.6424
#   Client 31 (User 31) local loss: 0.5587
#   Client 32 (User 32) local loss: 0.6137
#   Client 33 (User 33) local loss: 0.5658
#   Client 34 (User 34) local loss: 0.6027
#   Client 35 (User 35) local loss: 0.6641
#   Client 36 (User 36) local loss: 0.5044
#   Client 37 (User 37) local loss: 0.6531
#   Client 38 (User 38) local loss: 0.5435
#   Client 39 (User 39) local loss: 0.5931
#   Client 40 (User 40) local loss: 0.6646
#   Client 41 (User 41) local loss: 0.5619
#   Client 42 (User 42) local loss: 0.4712
#   Client 43 (User 43) local loss: 0.6394
#   Client 44 (User 44) local loss: 0.5695
#   Client 45 (User 45) local loss: 0.4833
#   Client 46 (User 46) local loss: 0.5859
#   Client 47 (User 47) local loss: 0.5874
#   Client 48 (User 48) local loss: 0.6149
#   Client 49 (User 49) local loss: 0.6048
#   Client 50 (User 50) local loss: 0.6106
#   Client 51 (User 51) local loss: 0.6098
#   Client 52 (User 52) local loss: 0.4966
#   Client 53 (User 53) local loss: 0.7069
#   Client 54 (User 54) local loss: 0.6228
#   Client 55 (User 55) local loss: 0.5692
#   Client 56 (User 56) local loss: 0.4994
#   Client 57 (User 57) local loss: 0.6635
#   Client 58 (User 58) local loss: 0.5480
#   Client 59 (User 59) local loss: 0.5922
#   Client 60 (User 60) local loss: 0.6731
#   Client 61 (User 61) local loss: 0.6428
#   Client 62 (User 62) local loss: 0.6707
#   Client 63 (User 63) local loss: 0.5462
#   Client 64 (User 64) local loss: 0.5002
#   Client 65 (User 65) local loss: 0.5722
#   Client 66 (User 66) local loss: 0.6866
#   Client 67 (User 67) local loss: 0.5830
#   Client 68 (User 68) local loss: 0.5100
#   Client 69 (User 69) local loss: 0.6456
#   Client 70 (User 70) local loss: 0.5753
#   Client 71 (User 71) local loss: 0.6081
#   Client 72 (User 72) local loss: 0.6848
#   Client 73 (User 73) local loss: 0.5633
#   Client 74 (User 74) local loss: 0.6376
#   Client 75 (User 75) local loss: 0.5839
#   Client 76 (User 76) local loss: 0.5530
#   Client 77 (User 77) local loss: 0.5612
#   Client 78 (User 78) local loss: 0.6179
#   Client 79 (User 79) local loss: 0.5376
#   Client 80 (User 80) local loss: 0.5621
#   Client 81 (User 81) local loss: 0.4259
#   Client 82 (User 82) local loss: 0.5873
#   Client 83 (User 83) local loss: 0.5516
#   Client 84 (User 84) local loss: 0.5858
#   Client 85 (User 85) local loss: 0.5421
#   Client 86 (User 86) local loss: 0.6864
#   Client 87 (User 87) local loss: 0.6325
#   Client 88 (User 88) local loss: 0.5702
#   Client 89 (User 89) local loss: 0.5875
#   Client 90 (User 90) local loss: 0.6236
#   Client 91 (User 91) local loss: 0.5463
#   Client 92 (User 92) local loss: 0.4906
#   Client 93 (User 93) local loss: 0.5654
#   Client 94 (User 94) local loss: 0.6194
#   Client 95 (User 95) local loss: 0.6075
#   Client 96 (User 96) local loss: 0.6130
#   Client 97 (User 97) local loss: 0.5607
#   Client 98 (User 98) local loss: 0.5859
#   Client 99 (User 99) local loss: 0.5617
# Round 9 completed. Global item embeddings updated.
#
# --- Communication Round 10/10 ---
#   Client 0 (User 0) local loss: 0.5819
#   Client 1 (User 1) local loss: 0.5752
#   Client 2 (User 2) local loss: 0.5143
#   Client 3 (User 3) local loss: 0.6684
#   Client 4 (User 4) local loss: 0.5941
#   Client 5 (User 5) local loss: 0.6546
#   Client 6 (User 6) local loss: 0.4762
#   Client 7 (User 7) local loss: 0.4970
#   Client 8 (User 8) local loss: 0.5050
#   Client 9 (User 9) local loss: 0.5131
#   Client 10 (User 10) local loss: 0.6099
#   Client 11 (User 11) local loss: 0.5380
#   Client 12 (User 12) local loss: 0.4472
#   Client 13 (User 13) local loss: 0.6012
#   Client 14 (User 14) local loss: 0.6364
#   Client 15 (User 15) local loss: 0.5680
#   Client 16 (User 16) local loss: 0.6241
#   Client 17 (User 17) local loss: 0.5700
#   Client 18 (User 18) local loss: 0.6005
#   Client 19 (User 19) local loss: 0.6179
#   Client 20 (User 20) local loss: 0.5861
#   Client 21 (User 21) local loss: 0.4999
#   Client 22 (User 22) local loss: 0.5902
#   Client 23 (User 23) local loss: 0.5750
#   Client 24 (User 24) local loss: 0.4324
#   Client 25 (User 25) local loss: 0.5957
#   Client 26 (User 26) local loss: 0.4934
#   Client 27 (User 27) local loss: 0.6070
#   Client 28 (User 28) local loss: 0.6863
#   Client 29 (User 29) local loss: 0.5746
#   Client 30 (User 30) local loss: 0.6356
#   Client 31 (User 31) local loss: 0.5355
#   Client 32 (User 32) local loss: 0.6007
#   Client 33 (User 33) local loss: 0.5573
#   Client 34 (User 34) local loss: 0.5906
#   Client 35 (User 35) local loss: 0.6479
#   Client 36 (User 36) local loss: 0.5198
#   Client 37 (User 37) local loss: 0.6524
#   Client 38 (User 38) local loss: 0.5388
#   Client 39 (User 39) local loss: 0.5842
#   Client 40 (User 40) local loss: 0.6564
#   Client 41 (User 41) local loss: 0.5630
#   Client 42 (User 42) local loss: 0.4621
#   Client 43 (User 43) local loss: 0.6417
#   Client 44 (User 44) local loss: 0.5675
#   Client 45 (User 45) local loss: 0.4801
#   Client 46 (User 46) local loss: 0.5842
#   Client 47 (User 47) local loss: 0.5814
#   Client 48 (User 48) local loss: 0.5953
#   Client 49 (User 49) local loss: 0.6002
#   Client 50 (User 50) local loss: 0.6094
#   Client 51 (User 51) local loss: 0.6012
#   Client 52 (User 52) local loss: 0.4939
#   Client 53 (User 53) local loss: 0.6984
#   Client 54 (User 54) local loss: 0.6099
#   Client 55 (User 55) local loss: 0.5675
#   Client 56 (User 56) local loss: 0.4921
#   Client 57 (User 57) local loss: 0.6406
#   Client 58 (User 58) local loss: 0.5428
#   Client 59 (User 59) local loss: 0.5835
#   Client 60 (User 60) local loss: 0.6639
#   Client 61 (User 61) local loss: 0.6377
#   Client 62 (User 62) local loss: 0.6719
#   Client 63 (User 63) local loss: 0.5327
#   Client 64 (User 64) local loss: 0.5034
#   Client 65 (User 65) local loss: 0.5659
#   Client 66 (User 66) local loss: 0.6878
#   Client 67 (User 67) local loss: 0.5681
#   Client 68 (User 68) local loss: 0.5099
#   Client 69 (User 69) local loss: 0.6439
#   Client 70 (User 70) local loss: 0.5815
#   Client 71 (User 71) local loss: 0.6005
#   Client 72 (User 72) local loss: 0.6704
#   Client 73 (User 73) local loss: 0.5635
#   Client 74 (User 74) local loss: 0.6378
#   Client 75 (User 75) local loss: 0.5813
#   Client 76 (User 76) local loss: 0.5418
#   Client 77 (User 77) local loss: 0.5590
#   Client 78 (User 78) local loss: 0.6033
#   Client 79 (User 79) local loss: 0.5386
#   Client 80 (User 80) local loss: 0.5652
#   Client 81 (User 81) local loss: 0.4251
#   Client 82 (User 82) local loss: 0.5833
#   Client 83 (User 83) local loss: 0.5487
#   Client 84 (User 84) local loss: 0.5809
#   Client 85 (User 85) local loss: 0.5198
#   Client 86 (User 86) local loss: 0.6822
#   Client 87 (User 87) local loss: 0.6437
#   Client 88 (User 88) local loss: 0.5602
#   Client 89 (User 89) local loss: 0.5902
#   Client 90 (User 90) local loss: 0.6179
#   Client 91 (User 91) local loss: 0.5413
#   Client 92 (User 92) local loss: 0.4815
#   Client 93 (User 93) local loss: 0.5728
#   Client 94 (User 94) local loss: 0.6214
#   Client 95 (User 95) local loss: 0.5963
#   Client 96 (User 96) local loss: 0.6059
#   Client 97 (User 97) local loss: 0.5674
#   Client 98 (User 98) local loss: 0.5794
#   Client 99 (User 99) local loss: 0.5776
# Round 10 completed. Global item embeddings updated.
# Federated training completed.
